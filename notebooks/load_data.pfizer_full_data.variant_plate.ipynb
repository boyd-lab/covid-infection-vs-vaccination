# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
import pandas as pd
import seaborn as sns
import anndata
import scanpy as sc
import genetools
from covid_serology import config, helpers
from numpy.testing import assert_array_equal

# %% [markdown]
# # Load data

# %%
vaccine_participants = pd.read_csv(
    f"{config.paths.data_dir}/pfizer_demographics.csv"
).dropna(how="all")
vaccine_participants
# Out:
#          PID COVID Positive Ever?
# 0   pfizer00                   No
# 1   pfizer01                   No
# 2   pfizer02                   No
# 3   pfizer03                   No
# 4   pfizer04                   No
# 5   pfizer05                   No
# 6   pfizer06                   No
# 7   pfizer07                   No
# 8   pfizer08                   No
# 9   pfizer09                   No
# 10  pfizer10                   No
# 11  pfizer11                   No
# 12  pfizer12                   No
# 13  pfizer13                   No
# 14  pfizer14                   No
# 15  pfizer15                  Yes
# 16  pfizer16                   No
# 17  pfizer17                   No
# 18  pfizer18                   No
# 19  pfizer19                   No
# 20  pfizer20                   No
# 21  pfizer21                   No
# 22  pfizer22                  Yes
# 23  pfizer23                   No
# 24  pfizer24                   No
# 25  pfizer25                  Yes
# 26  pfizer26                  NaN
# 27  pfizer27                   No
# 28  pfizer28                   No
# 29  pfizer29                   No
# 30  pfizer30                   No
# 31  pfizer31                   No
# 32  pfizer32                  Yes
# 33  pfizer33                   No
# 34  pfizer34                   No
# 35  pfizer35                   No
# 36  pfizer36                   No
# 37  pfizer37                   No
# 38  pfizer38                   No
# 39  pfizer39                  NaN
# 40  pfizer40                   No
# 41  pfizer41                  NaN
# 42  pfizer42                   No
# 43  pfizer43                   No
# 44  pfizer44                   No
# 45  pfizer45                   No
# 46  pfizer46                   No
# 47  pfizer47                   No
# 48  pfizer48                   No
# 49  pfizer49                   No
# 50  pfizer50                   No
# 51  pfizer51                   No
# 52  pfizer52                   No
# 53  pfizer53                   No
# 54  pfizer54                   No
# 55  pfizer55                   No
# 56  pfizer56                   No
# 57  pfizer57                   No
# 58  pfizer58                   No
# 59  pfizer59                   No

# %%
vaccine_df = pd.read_csv(f"{config.paths.data_dir}/pfizer_p11_boost.csv")
vaccine_df
# Out:
#     participant  timepoint  Epsilon_ECL     Epsilon_AU  Beta_ECL  \
# 0      pfizer00         D0         3828    1017.034757      3192
# 1      pfizer01         D0          522     113.485400       381
# 2      pfizer02         D0          412      84.060552       301
# 3      pfizer03         D0          497     106.787884       345
# 4      pfizer04         D0          583     129.848939       392
# ..          ...        ...          ...            ...       ...
# 239    pfizer56  boostD1/2         8635    5892.465854      3168
# 240    pfizer57  boostD1/2         1433     938.392743       592
# 241    pfizer58  boostD1/2        10405    7107.068865      2892
# 242    pfizer59  boostD1/2         3573    2413.490746      1184
# 243    pfizer59   boostD21       211494  144124.709400     83591
#
#           Beta_AU  Iota_ECL        Iota_AU  Gamma_ECL      Gamma_AU  ...  \
# 0     1418.890256      3273    1095.909180       3539    861.203717  ...
# 1      128.472408       479     127.293665        349     58.639990  ...
# 2       93.482610       376      93.242917        410     73.095575  ...
# 3      112.690197       469     123.974357        385     67.158179  ...
# 4      133.305522       447     116.681383        540    104.211471  ...
# ..            ...       ...            ...        ...           ...  ...
# 239   2120.916452      5415    3940.827746       4831   2994.041935  ...
# 240    326.020256      1009     643.872038        757    409.771568  ...
# 241   1923.301930      5387    3919.405017       5004   3105.440737  ...
# 242    724.991395      1975    1348.432754       1915   1133.350791  ...
# 243  66727.808980    140692  116916.823300     136479  92483.669070  ...
#
#      Alpha_ECL       Alpha_AU  P.3_ECL        P.3_AU  Kappa_ECL  \
# 0         3736     915.731658     3299   1104.856408       4013
# 1          425      81.016962      258     55.965723        516
# 2          395      73.670487      331     79.196105        415
# 3          402      75.383592      287     65.154067        537
# 4          500      99.430972      414    105.956261        581
# ..         ...            ...      ...           ...        ...
# 239       5971    3688.680554     3292   2419.424349       7143
# 240       1020     571.777118      568    347.255339       1113
# 241       6598    4088.066259     3323   2443.507295       7984
# 242       2750    1650.496368     1256    858.800469       2752
# 243     188206  124842.781200    90653  75864.212440     158921
#
#           Kappa_AU  Delta_ECL       Delta_AU  Wuhan_ECL       Wuhan_AU
# 0      1131.699710       4017     811.480795       3779     954.841762
# 1       116.340069        464      74.591103        581     124.307340
# 2        88.286803        365      54.959538        488     100.904751
# 3       122.197315        451      72.004871        541     114.228705
# 4       134.493574        437      69.222333        668     146.288540
# ..             ...        ...            ...        ...            ...
# 239    5900.000081       8584    4565.699428       9193    6073.602207
# 240     862.419928       1417     720.005216       1431     888.851983
# 241    6603.373993      10157    5408.961427      10566    6995.486658
# 242    2230.211687       3407    1788.710763       4128    2682.861959
# 243  133355.423700     209294  111905.830700     249188  169984.750400
#
# [244 rows x 22 columns]

# %%
# only one sample per patient per timepoint
assert all(vaccine_df.groupby(["participant", "timepoint"]).size() == 1)

# %% [markdown]
# # Reshape vaccine data

# %%
vaccine_df.columns
# Out:
# Index(['participant', 'timepoint', 'Epsilon_ECL', 'Epsilon_AU', 'Beta_ECL',
#        'Beta_AU', 'Iota_ECL', 'Iota_AU', 'Gamma_ECL', 'Gamma_AU',
#        'B.1.526.2_ECL', 'B.1.526.2_AU', 'Alpha_ECL', 'Alpha_AU', 'P.3_ECL',
#        'P.3_AU', 'Kappa_ECL', 'Kappa_AU', 'Delta_ECL', 'Delta_AU', 'Wuhan_ECL',
#        'Wuhan_AU'],
#       dtype='object')

# %%
vaccine_df = pd.melt(
    vaccine_df, id_vars=["participant", "timepoint"], var_name="measurement"
)
vaccine_df
# Out:
#      participant  timepoint  measurement          value
# 0       pfizer00         D0  Epsilon_ECL    3828.000000
# 1       pfizer01         D0  Epsilon_ECL     522.000000
# 2       pfizer02         D0  Epsilon_ECL     412.000000
# 3       pfizer03         D0  Epsilon_ECL     497.000000
# 4       pfizer04         D0  Epsilon_ECL     583.000000
# ...          ...        ...          ...            ...
# 4875    pfizer56  boostD1/2     Wuhan_AU    6073.602207
# 4876    pfizer57  boostD1/2     Wuhan_AU     888.851983
# 4877    pfizer58  boostD1/2     Wuhan_AU    6995.486658
# 4878    pfizer59  boostD1/2     Wuhan_AU    2682.861959
# 4879    pfizer59   boostD21     Wuhan_AU  169984.750400
#
# [4880 rows x 4 columns]

# %%
vaccine_df = vaccine_df[vaccine_df["measurement"].str.contains("AU")].copy()
vaccine_df
# Out:
#      participant  timepoint measurement          value
# 244     pfizer00         D0  Epsilon_AU    1017.034757
# 245     pfizer01         D0  Epsilon_AU     113.485400
# 246     pfizer02         D0  Epsilon_AU      84.060552
# 247     pfizer03         D0  Epsilon_AU     106.787884
# 248     pfizer04         D0  Epsilon_AU     129.848939
# ...          ...        ...         ...            ...
# 4875    pfizer56  boostD1/2    Wuhan_AU    6073.602207
# 4876    pfizer57  boostD1/2    Wuhan_AU     888.851983
# 4877    pfizer58  boostD1/2    Wuhan_AU    6995.486658
# 4878    pfizer59  boostD1/2    Wuhan_AU    2682.861959
# 4879    pfizer59   boostD21    Wuhan_AU  169984.750400
#
# [2440 rows x 4 columns]

# %%
# just in case, convert to float and switch non-numeric values to nan
vaccine_df["value"] = pd.to_numeric(vaccine_df["value"], errors="coerce")
vaccine_df.dtypes
# Out:
# participant     object
# timepoint       object
# measurement     object
# value          float64
# dtype: object

# %%
vaccine_df["value"].isna().value_counts()
# Out:
# False    2440
# Name: value, dtype: int64

# %%
vaccine_df[vaccine_df["value"].isna()]
# Out:
# Empty DataFrame
# Columns: [participant, timepoint, measurement, value]
# Index: []

# %%
measurement_cols = vaccine_df["measurement"].unique()
helpers.confirm_all_measurement_columns_are_present(measurement_cols)
measurement_cols
# Out:
# array(['Epsilon_AU', 'Beta_AU', 'Iota_AU', 'Gamma_AU', 'B.1.526.2_AU',
#        'Alpha_AU', 'P.3_AU', 'Kappa_AU', 'Delta_AU', 'Wuhan_AU'],
#       dtype=object)

# %%
vaccine_df["measurement"] = vaccine_df["measurement"].str.replace("_AU", "")
vaccine_df["measurement"].value_counts()
# Out:
# Gamma        244
# Wuhan        244
# Beta         244
# P.3          244
# Epsilon      244
# Kappa        244
# Iota         244
# Alpha        244
# B.1.526.2    244
# Delta        244
# Name: measurement, dtype: int64

# %%
# extract parts of measurement column
# all variant plate measurements are IgG only
measurement_parts = (
    vaccine_df["measurement"]
    .rename("virus")
    .to_frame()
    .assign(variant_plate_type="Variant", target="RBD", antibody="IgG")
    .apply(lambda col: col.str.strip())
)
measurement_parts
# Out:
#         virus variant_plate_type target antibody
# 244   Epsilon            Variant    RBD      IgG
# 245   Epsilon            Variant    RBD      IgG
# 246   Epsilon            Variant    RBD      IgG
# 247   Epsilon            Variant    RBD      IgG
# 248   Epsilon            Variant    RBD      IgG
# ...       ...                ...    ...      ...
# 4875    Wuhan            Variant    RBD      IgG
# 4876    Wuhan            Variant    RBD      IgG
# 4877    Wuhan            Variant    RBD      IgG
# 4878    Wuhan            Variant    RBD      IgG
# 4879    Wuhan            Variant    RBD      IgG
#
# [2440 rows x 4 columns]

# %%
measurement_parts["virus"].value_counts()
# Out:
# Gamma        244
# Wuhan        244
# Beta         244
# P.3          244
# Epsilon      244
# Kappa        244
# Iota         244
# Alpha        244
# B.1.526.2    244
# Delta        244
# Name: virus, dtype: int64

# %%
measurement_parts["target"].value_counts()
# Out:
# RBD    2440
# Name: target, dtype: int64

# %%
measurement_parts["variant_plate_type"].value_counts()
# Out:
# Variant    2440
# Name: variant_plate_type, dtype: int64

# %%
vaccine_df = pd.concat([vaccine_df, measurement_parts], axis=1)
vaccine_df
# Out:
#      participant  timepoint measurement          value    virus  \
# 244     pfizer00         D0     Epsilon    1017.034757  Epsilon
# 245     pfizer01         D0     Epsilon     113.485400  Epsilon
# 246     pfizer02         D0     Epsilon      84.060552  Epsilon
# 247     pfizer03         D0     Epsilon     106.787884  Epsilon
# 248     pfizer04         D0     Epsilon     129.848939  Epsilon
# ...          ...        ...         ...            ...      ...
# 4875    pfizer56  boostD1/2       Wuhan    6073.602207    Wuhan
# 4876    pfizer57  boostD1/2       Wuhan     888.851983    Wuhan
# 4877    pfizer58  boostD1/2       Wuhan    6995.486658    Wuhan
# 4878    pfizer59  boostD1/2       Wuhan    2682.861959    Wuhan
# 4879    pfizer59   boostD21       Wuhan  169984.750400    Wuhan
#
#      variant_plate_type target antibody
# 244             Variant    RBD      IgG
# 245             Variant    RBD      IgG
# 246             Variant    RBD      IgG
# 247             Variant    RBD      IgG
# 248             Variant    RBD      IgG
# ...                 ...    ...      ...
# 4875            Variant    RBD      IgG
# 4876            Variant    RBD      IgG
# 4877            Variant    RBD      IgG
# 4878            Variant    RBD      IgG
# 4879            Variant    RBD      IgG
#
# [2440 rows x 8 columns]

# %%
vaccine_df["timepoint"].value_counts()
# Out:
# D21          450
# D28          440
# D0           430
# D90          370
# D210         350
# boostD1/2    220
# boostD7/8    150
# boostD21      30
# Name: timepoint, dtype: int64

# %%
# timepoint label map
map_vaccine_to_global_timepoint_labels = {
    "D0": "day 0 / pre-pandemic",
    "D7": "day 7 / week 1",
    "D21": "day 21 / weeks 2&3",
    "D28": "day 28 / week 4",
    "D42": "day 42 / weeks 5&6",
    "D90": "week 7 and later / 3 months",
    "D210": "day 210 / 7 months",
    "boostD1/2": "boostD1/2",
    "boostD7/8": "boostD7/8",
    "boostD21": "boostD21",
}
assert all(
    tp in map_vaccine_to_global_timepoint_labels.keys()
    for tp in vaccine_df["timepoint"].unique()
)

# %%
def process_vaccine_timepoint(df_partial, timepoint):
    # at a given time point: only one measurement per patient-virus-target combo
    assert all(
        df_partial.groupby(
            ["participant", "virus", "target", "variant_plate_type", "antibody"]
        ).size()
        == 1
    )

    # unmelt
    vaccine_df_pivot = pd.pivot(
        df_partial,
        index="participant",
        columns=["virus", "target", "variant_plate_type", "antibody"],
        values="value",
    )

    ## set column names
    variable_info = vaccine_df_pivot.columns.to_frame().reset_index(drop=True)
    # create combined name
    variable_info["timepoint"] = timepoint
    variable_info["combined_name"] = variable_info.apply("_".join, axis=1)
    variable_info = variable_info.set_index("combined_name")

    # set var names
    vaccine_df_pivot.columns = variable_info.index.copy()

    # drop patients with any NaNs in this timepoint
    vaccine_df_pivot = vaccine_df_pivot.dropna(how="any")
    assert not vaccine_df_pivot.isna().any().any()

    return vaccine_df_pivot, variable_info

# %%
X_partial = []
var_partial = []
for vaccine_timepoint in vaccine_df["timepoint"].unique():
    associated_global_timepoint_label = map_vaccine_to_global_timepoint_labels[
        vaccine_timepoint
    ]
    print(vaccine_timepoint, "->", associated_global_timepoint_label)
    df_partial = vaccine_df[vaccine_df["timepoint"] == vaccine_timepoint]
    vaccine_df_pivot, variable_info = process_vaccine_timepoint(
        df_partial, associated_global_timepoint_label
    )
    X_partial.append(vaccine_df_pivot)
    var_partial.append(variable_info)
vaccine_df_pivot = pd.concat(X_partial, axis=1)
variable_info = pd.concat(var_partial, axis=0)
# Out:
# D0 -> day 0 / pre-pandemic
# D21 -> day 21 / weeks 2&3
# D28 -> day 28 / week 4
# D90 -> week 7 and later / 3 months
# D210 -> day 210 / 7 months
# boostD1/2 -> boostD1/2
# boostD7/8 -> boostD7/8
# boostD21 -> boostD21

# %%
# note: there are NaNs - patients don't have entries for all timepoints
vaccine_df_pivot
# Out:
# combined_name  Epsilon_RBD_Variant_IgG_day 0 / pre-pandemic  \
# participant
# pfizer00                                        1017.034757
# pfizer01                                         113.485400
# pfizer02                                          84.060552
# pfizer03                                         106.787884
# pfizer04                                         129.848939
# pfizer05                                          95.816259
# pfizer06                                         113.485400
# pfizer07                                         108.394789
# pfizer08                                         118.310900
# pfizer09                                         266.164673
# pfizer11                                         365.599703
# pfizer12                                         235.828263
# pfizer13                                         165.887928
# pfizer14                                         240.700410
# pfizer15                                         288.947652
# pfizer16                                         108.248474
# pfizer17                                          47.560963
# pfizer19                                         127.595438
# pfizer20                                         101.718514
# pfizer22                                         146.981030
# pfizer23                                          72.948950
# pfizer24                                          96.552837
# pfizer25                                        2265.689980
# pfizer26                                         720.378974
# pfizer29                                         187.494095
# pfizer32                                         333.514782
# pfizer33                                          31.736576
# pfizer34                                          25.751699
# pfizer36                                          68.665375
# pfizer37                                          22.052443
# pfizer38                                          48.024934
# pfizer40                                          41.159941
# pfizer42                                          40.016664
# pfizer43                                          25.182277
# pfizer44                                          68.091245
# pfizer45                                          38.016588
# pfizer46                                          26.890856
# pfizer47                                          33.448358
# pfizer48                                          36.874078
# pfizer49                                          28.885339
# pfizer55                                          46.307869
# pfizer56                                         194.349615
# pfizer58                                         171.545968
# pfizer27                                                NaN
# pfizer28                                                NaN
# pfizer30                                                NaN
# pfizer31                                                NaN
# pfizer57                                                NaN
# pfizer18                                                NaN
# pfizer10                                                NaN
# pfizer52                                                NaN
# pfizer59                                                NaN
# pfizer35                                                NaN
#
# combined_name  Beta_RBD_Variant_IgG_day 0 / pre-pandemic  \
# participant
# pfizer00                                     1418.890256
# pfizer01                                      128.472408
# pfizer02                                       93.482610
# pfizer03                                      112.690197
# pfizer04                                      133.305522
# pfizer05                                       70.489811
# pfizer06                                      108.316480
# pfizer07                                      110.502755
# pfizer08                                      112.252616
# pfizer09                                      191.633555
# pfizer11                                      240.174124
# pfizer12                                      122.766879
# pfizer13                                      165.492846
# pfizer14                                      233.477126
# pfizer15                                      106.131395
# pfizer16                                      126.364345
# pfizer17                                       70.213733
# pfizer19                                      277.235716
# pfizer20                                      115.009541
# pfizer22                                      126.770853
# pfizer23                                       69.030319
# pfizer24                                       73.374371
# pfizer25                                      608.004358
# pfizer26                                      411.424445
# pfizer29                                      160.312113
# pfizer32                                      122.768921
# pfizer33                                       34.914174
# pfizer34                                       20.435264
# pfizer36                                       40.061746
# pfizer37                                       20.169752
# pfizer38                                       43.596596
# pfizer40                                       54.804233
# pfizer42                                       40.876598
# pfizer43                                       24.698044
# pfizer44                                       51.515312
# pfizer45                                       76.328155
# pfizer46                                       19.108870
# pfizer47                                       25.767717
# pfizer48                                       32.484360
# pfizer49                                       27.911402
# pfizer55                                       34.643911
# pfizer56                                      170.612618
# pfizer58                                      175.228064
# pfizer27                                             NaN
# pfizer28                                             NaN
# pfizer30                                             NaN
# pfizer31                                             NaN
# pfizer57                                             NaN
# pfizer18                                             NaN
# pfizer10                                             NaN
# pfizer52                                             NaN
# pfizer59                                             NaN
# pfizer35                                             NaN
#
# combined_name  Iota_RBD_Variant_IgG_day 0 / pre-pandemic  \
# participant
# pfizer00                                     1095.909180
# pfizer01                                      127.293665
# pfizer02                                       93.242917
# pfizer03                                      123.974357
# pfizer04                                      116.681383
# pfizer05                                       84.373942
# pfizer06                                      125.965625
# pfizer07                                       98.840305
# pfizer08                                      138.931366
# pfizer09                                      160.955107
# pfizer11                                      234.295961
# pfizer12                                       85.029976
# pfizer13                                      171.666865
# pfizer14                                      172.672145
# pfizer15                                      106.428362
# pfizer16                                      134.963334
# pfizer17                                       42.360234
# pfizer19                                      125.450629
# pfizer20                                      111.756416
# pfizer22                                      154.769056
# pfizer23                                       65.562273
# pfizer24                                       54.598646
# pfizer25                                     1093.128435
# pfizer26                                      391.865204
# pfizer29                                      168.617362
# pfizer32                                      203.436866
# pfizer33                                       36.981933
# pfizer34                                       24.188836
# pfizer36                                       38.663658
# pfizer37                                       25.016980
# pfizer38                                       43.724025
# pfizer40                                       43.160689
# pfizer42                                       36.981933
# pfizer43                                       20.063866
# pfizer44                                       61.587384
# pfizer45                                      189.173235
# pfizer46                                       26.122681
# pfizer47                                       22.810842
# pfizer48                                       45.133485
# pfizer49                                       24.464774
# pfizer55                                       40.347981
# pfizer56                                      171.819089
# pfizer58                                      154.271050
# pfizer27                                             NaN
# pfizer28                                             NaN
# pfizer30                                             NaN
# pfizer31                                             NaN
# pfizer57                                             NaN
# pfizer18                                             NaN
# pfizer10                                             NaN
# pfizer52                                             NaN
# pfizer59                                             NaN
# pfizer35                                             NaN
#
# combined_name  Gamma_RBD_Variant_IgG_day 0 / pre-pandemic  \
# participant
# pfizer00                                       861.203717
# pfizer01                                        58.639990
# pfizer02                                        73.095575
# pfizer03                                        67.158179
# pfizer04                                       104.211471
# pfizer05                                        56.752554
# pfizer06                                        86.931707
# pfizer07                                        78.095743
# pfizer08                                        79.526393
# pfizer09                                       260.059152
# pfizer11                                       170.522905
# pfizer12                                        91.481185
# pfizer13                                       121.589522
# pfizer14                                       265.275377
# pfizer15                                       116.511623
# pfizer16                                        57.933392
# pfizer17                                        21.825750
# pfizer19                                       109.111647
# pfizer20                                       112.618839
# pfizer22                                       130.224252
# pfizer23                                        47.025086
# pfizer24                                        57.689933
# pfizer25                                       821.962463
# pfizer26                                       163.700329
# pfizer29                                        87.681862
# pfizer32                                       211.990526
# pfizer33                                        29.270735
# pfizer34                                        20.126642
# pfizer36                                        32.664279
# pfizer37                                        35.095134
# pfizer38                                        40.950277
# pfizer40                                       115.728023
# pfizer42                                        37.287461
# pfizer43                                        24.685278
# pfizer44                                        68.332771
# pfizer45                                       134.471512
# pfizer46                                        16.075229
# pfizer47                                        34.365303
# pfizer48                                        32.907115
# pfizer49                                        25.166775
# pfizer55                                        29.028796
# pfizer56                                       103.360625
# pfizer58                                       175.910794
# pfizer27                                              NaN
# pfizer28                                              NaN
# pfizer30                                              NaN
# pfizer31                                              NaN
# pfizer57                                              NaN
# pfizer18                                              NaN
# pfizer10                                              NaN
# pfizer52                                              NaN
# pfizer59                                              NaN
# pfizer35                                              NaN
#
# combined_name  B.1.526.2_RBD_Variant_IgG_day 0 / pre-pandemic  \
# participant
# pfizer00                                           862.666390
# pfizer01                                            83.940808
# pfizer02                                            71.918525
# pfizer03                                            75.089555
# pfizer04                                           100.799579
# pfizer05                                            49.831210
# pfizer06                                            66.942754
# pfizer07                                           161.704607
# pfizer08                                            77.810314
# pfizer09                                           134.725290
# pfizer11                                           148.775758
# pfizer12                                            55.670459
# pfizer13                                            42.221970
# pfizer14                                           153.390031
# pfizer15                                           322.514587
# pfizer16                                           101.758779
# pfizer17                                            52.019539
# pfizer19                                            87.690095
# pfizer20                                           107.631481
# pfizer22                                           105.751567
# pfizer23                                            65.734443
# pfizer24                                            86.987686
# pfizer25                                          3184.196524
# pfizer26                                           257.041064
# pfizer29                                            75.063178
# pfizer32                                           270.036232
# pfizer33                                            34.921327
# pfizer34                                            23.587859
# pfizer36                                            48.390236
# pfizer37                                            17.427635
# pfizer38                                            47.939358
# pfizer40                                            40.966863
# pfizer42                                            45.011633
# pfizer43                                            22.704697
# pfizer44                                            61.059931
# pfizer45                                            40.293809
# pfizer46                                            33.581741
# pfizer47                                            31.575226
# pfizer48                                            38.500573
# pfizer49                                            30.462046
# pfizer55                                            40.293809
# pfizer56                                           146.052528
# pfizer58                                            83.713543
# pfizer27                                                  NaN
# pfizer28                                                  NaN
# pfizer30                                                  NaN
# pfizer31                                                  NaN
# pfizer57                                                  NaN
# pfizer18                                                  NaN
# pfizer10                                                  NaN
# pfizer52                                                  NaN
# pfizer59                                                  NaN
# pfizer35                                                  NaN
#
# combined_name  Alpha_RBD_Variant_IgG_day 0 / pre-pandemic  \
# participant
# pfizer00                                       915.731658
# pfizer01                                        81.016962
# pfizer02                                        73.670487
# pfizer03                                        75.383592
# pfizer04                                        99.430972
# pfizer05                                        62.430578
# pfizer06                                        70.735323
# pfizer07                                       169.126599
# pfizer08                                        84.204026
# pfizer09                                       276.073517
# pfizer11                                       139.393583
# pfizer12                                        71.713484
# pfizer13                                        64.383030
# pfizer14                                       357.593120
# pfizer15                                       290.093655
# pfizer16                                       107.110867
# pfizer17                                        48.739642
# pfizer19                                        88.065892
# pfizer20                                        94.233903
# pfizer22                                       103.759530
# pfizer23                                        74.222315
# pfizer24                                        88.065892
# pfizer25                                      2267.508369
# pfizer26                                       261.438408
# pfizer29                                        80.368813
# pfizer32                                       222.550967
# pfizer33                                        39.952416
# pfizer34                                        22.499487
# pfizer36                                        44.793311
# pfizer37                                        17.990136
# pfizer38                                        56.047944
# pfizer40                                        41.734429
# pfizer42                                        44.283157
# pfizer43                                        26.777518
# pfizer44                                        64.266406
# pfizer45                                        48.879197
# pfizer46                                        22.248384
# pfizer47                                        35.378613
# pfizer48                                        43.008362
# pfizer49                                        25.265704
# pfizer55                                        37.155802
# pfizer56                                       124.417039
# pfizer58                                        96.234710
# pfizer27                                              NaN
# pfizer28                                              NaN
# pfizer30                                              NaN
# pfizer31                                              NaN
# pfizer57                                              NaN
# pfizer18                                              NaN
# pfizer10                                              NaN
# pfizer52                                              NaN
# pfizer59                                              NaN
# pfizer35                                              NaN
#
# combined_name  P.3_RBD_Variant_IgG_day 0 / pre-pandemic  \
# participant
# pfizer00                                    1104.856408
# pfizer01                                      55.965723
# pfizer02                                      79.196105
# pfizer03                                      65.154067
# pfizer04                                     105.956261
# pfizer05                                      57.861961
# pfizer06                                      85.935731
# pfizer07                                      70.565899
# pfizer08                                     109.200940
# pfizer09                                     218.726746
# pfizer11                                     214.384877
# pfizer12                                      49.978882
# pfizer13                                     121.240140
# pfizer14                                     204.379160
# pfizer15                                      73.757453
# pfizer16                                      80.277793
# pfizer17                                      18.843133
# pfizer19                                      90.898682
# pfizer20                                      91.253421
# pfizer22                                     122.268787
# pfizer23                                      48.363348
# pfizer24                                      63.379945
# pfizer25                                     593.414704
# pfizer26                                     141.651837
# pfizer29                                     130.872234
# pfizer32                                      94.497216
# pfizer33                                      31.786322
# pfizer34                                      12.423158
# pfizer36                                      24.564519
# pfizer37                                      14.092495
# pfizer38                                      31.535573
# pfizer40                                      43.943737
# pfizer42                                      38.597234
# pfizer43                                      18.435283
# pfizer44                                      49.070865
# pfizer45                                      69.078936
# pfizer46                                      21.119638
# pfizer47                                      22.838334
# pfizer48                                      19.408969
# pfizer49                                      20.385477
# pfizer55                                      29.034542
# pfizer56                                      96.579693
# pfizer58                                     121.892365
# pfizer27                                            NaN
# pfizer28                                            NaN
# pfizer30                                            NaN
# pfizer31                                            NaN
# pfizer57                                            NaN
# pfizer18                                            NaN
# pfizer10                                            NaN
# pfizer52                                            NaN
# pfizer59                                            NaN
# pfizer35                                            NaN
#
# combined_name  Kappa_RBD_Variant_IgG_day 0 / pre-pandemic  \
# participant
# pfizer00                                      1131.699710
# pfizer01                                       116.340069
# pfizer02                                        88.286803
# pfizer03                                       122.197315
# pfizer04                                       134.493574
# pfizer05                                        71.729805
# pfizer06                                        78.893216
# pfizer07                                        83.033966
# pfizer08                                        94.379438
# pfizer09                                        78.617369
# pfizer11                                        64.311074
# pfizer12                                        64.036728
# pfizer13                                       105.761482
# pfizer14                                       163.110269
# pfizer15                                       141.493654
# pfizer16                                       126.202111
# pfizer17                                        52.244647
# pfizer19                                       164.484290
# pfizer20                                       123.026373
# pfizer22                                       141.536143
# pfizer23                                        97.428151
# pfizer24                                        98.861341
# pfizer25                                      1749.488472
# pfizer26                                       409.058249
# pfizer29                                        87.699736
# pfizer32                                       319.507742
# pfizer33                                        48.643653
# pfizer34                                        30.947539
# pfizer36                                        63.355043
# pfizer37                                        18.514379
# pfizer38                                        56.942431
# pfizer40                                        49.598859
# pfizer42                                        62.712733
# pfizer43                                        20.364603
# pfizer44                                        58.223045
# pfizer45                                        51.511167
# pfizer46                                        58.863719
# pfizer47                                        24.703682
# pfizer48                                        42.292760
# pfizer49                                        33.457875
# pfizer55                                        40.393688
# pfizer56                                       274.866667
# pfizer58                                        58.830271
# pfizer27                                              NaN
# pfizer28                                              NaN
# pfizer30                                              NaN
# pfizer31                                              NaN
# pfizer57                                              NaN
# pfizer18                                              NaN
# pfizer10                                              NaN
# pfizer52                                              NaN
# pfizer59                                              NaN
# pfizer35                                              NaN
#
# combined_name  Delta_RBD_Variant_IgG_day 0 / pre-pandemic  \
# participant
# pfizer00                                       811.480795
# pfizer01                                        74.591103
# pfizer02                                        54.959538
# pfizer03                                        72.004871
# pfizer04                                        69.222333
# pfizer05                                        58.517283
# pfizer06                                        51.801985
# pfizer07                                        68.030678
# pfizer08                                        60.694187
# pfizer09                                        97.160235
# pfizer11                                       114.831079
# pfizer12                                        39.027947
# pfizer13                                        30.050288
# pfizer14                                       145.916864
# pfizer15                                       170.259147
# pfizer16                                        94.052383
# pfizer17                                        50.898387
# pfizer19                                        77.663997
# pfizer20                                        62.411998
# pfizer22                                        72.647527
# pfizer23                                        51.332245
# pfizer24                                        64.805565
# pfizer25                                      1674.642284
# pfizer26                                       262.627206
# pfizer29                                        62.847098
# pfizer32                                       253.896784
# pfizer33                                        32.863036
# pfizer34                                        19.035629
# pfizer36                                        58.697669
# pfizer37                                        11.724875
# pfizer38                                        43.847318
# pfizer40                                        36.445212
# pfizer42                                        43.398219
# pfizer43                                        20.591632
# pfizer44                                        57.120098
# pfizer45                                        37.117388
# pfizer46                                        23.930882
# pfizer47                                        28.839109
# pfizer48                                        34.429652
# pfizer49                                        25.268309
# pfizer55                                        34.205793
# pfizer56                                       106.096604
# pfizer58                                        67.236535
# pfizer27                                              NaN
# pfizer28                                              NaN
# pfizer30                                              NaN
# pfizer31                                              NaN
# pfizer57                                              NaN
# pfizer18                                              NaN
# pfizer10                                              NaN
# pfizer52                                              NaN
# pfizer59                                              NaN
# pfizer35                                              NaN
#
# combined_name  Wuhan_RBD_Variant_IgG_day 0 / pre-pandemic  ...  \
# participant                                                ...
# pfizer00                                       954.841762  ...
# pfizer01                                       124.307340  ...
# pfizer02                                       100.904751  ...
# pfizer03                                       114.228705  ...
# pfizer04                                       146.288540  ...
# pfizer05                                        86.618318  ...
# pfizer06                                       107.436514  ...
# pfizer07                                       187.405854  ...
# pfizer08                                       127.082166  ...
# pfizer09                                       256.361144  ...
# pfizer11                                       274.310084  ...
# pfizer12                                       189.950941  ...
# pfizer13                                        87.619286  ...
# pfizer14                                       234.603126  ...
# pfizer15                                       369.836206  ...
# pfizer16                                       144.355366  ...
# pfizer17                                        58.135895  ...
# pfizer19                                       142.731309  ...
# pfizer20                                       150.856719  ...
# pfizer22                                       172.311528  ...
# pfizer23                                        81.737007  ...
# pfizer24                                       134.348812  ...
# pfizer25                                      3619.713649  ...
# pfizer26                                       352.276501  ...
# pfizer29                                       121.668396  ...
# pfizer32                                       299.719891  ...
# pfizer33                                        47.728802  ...
# pfizer34                                        29.496417  ...
# pfizer36                                        69.551997  ...
# pfizer37                                        22.130446  ...
# pfizer38                                        60.952032  ...
# pfizer40                                        45.921167  ...
# pfizer42                                        61.212168  ...
# pfizer43                                        26.949939  ...
# pfizer44                                        78.705366  ...
# pfizer45                                        45.663092  ...
# pfizer46                                        28.731811  ...
# pfizer47                                        41.024845  ...
# pfizer48                                        43.857707  ...
# pfizer49                                        33.839156  ...
# pfizer55                                        45.921167  ...
# pfizer56                                       182.386697  ...
# pfizer58                                       130.363214  ...
# pfizer27                                              NaN  ...
# pfizer28                                              NaN  ...
# pfizer30                                              NaN  ...
# pfizer31                                              NaN  ...
# pfizer57                                              NaN  ...
# pfizer18                                              NaN  ...
# pfizer10                                              NaN  ...
# pfizer52                                              NaN  ...
# pfizer59                                              NaN  ...
# pfizer35                                              NaN  ...
#
# combined_name  Epsilon_RBD_Variant_IgG_boostD21  \
# participant
# pfizer00                                    NaN
# pfizer01                                    NaN
# pfizer02                                    NaN
# pfizer03                                    NaN
# pfizer04                                    NaN
# pfizer05                                    NaN
# pfizer06                                    NaN
# pfizer07                                    NaN
# pfizer08                                    NaN
# pfizer09                                    NaN
# pfizer11                                    NaN
# pfizer12                                    NaN
# pfizer13                                    NaN
# pfizer14                            55795.08209
# pfizer15                                    NaN
# pfizer16                                    NaN
# pfizer17                                    NaN
# pfizer19                                    NaN
# pfizer20                                    NaN
# pfizer22                            39133.18674
# pfizer23                                    NaN
# pfizer24                                    NaN
# pfizer25                                    NaN
# pfizer26                                    NaN
# pfizer29                                    NaN
# pfizer32                                    NaN
# pfizer33                                    NaN
# pfizer34                                    NaN
# pfizer36                                    NaN
# pfizer37                                    NaN
# pfizer38                                    NaN
# pfizer40                                    NaN
# pfizer42                                    NaN
# pfizer43                                    NaN
# pfizer44                                    NaN
# pfizer45                                    NaN
# pfizer46                                    NaN
# pfizer47                                    NaN
# pfizer48                                    NaN
# pfizer49                                    NaN
# pfizer55                                    NaN
# pfizer56                                    NaN
# pfizer58                                    NaN
# pfizer27                                    NaN
# pfizer28                                    NaN
# pfizer30                                    NaN
# pfizer31                                    NaN
# pfizer57                                    NaN
# pfizer18                                    NaN
# pfizer10                                    NaN
# pfizer52                                    NaN
# pfizer59                           144124.70940
# pfizer35                                    NaN
#
# combined_name  Beta_RBD_Variant_IgG_boostD21  Iota_RBD_Variant_IgG_boostD21  \
# participant
# pfizer00                                 NaN                            NaN
# pfizer01                                 NaN                            NaN
# pfizer02                                 NaN                            NaN
# pfizer03                                 NaN                            NaN
# pfizer04                                 NaN                            NaN
# pfizer05                                 NaN                            NaN
# pfizer06                                 NaN                            NaN
# pfizer07                                 NaN                            NaN
# pfizer08                                 NaN                            NaN
# pfizer09                                 NaN                            NaN
# pfizer11                                 NaN                            NaN
# pfizer12                                 NaN                            NaN
# pfizer13                                 NaN                            NaN
# pfizer14                         27252.56782                    48165.86055
# pfizer15                                 NaN                            NaN
# pfizer16                                 NaN                            NaN
# pfizer17                                 NaN                            NaN
# pfizer19                                 NaN                            NaN
# pfizer20                                 NaN                            NaN
# pfizer22                         16758.69441                    28837.58049
# pfizer23                                 NaN                            NaN
# pfizer24                                 NaN                            NaN
# pfizer25                                 NaN                            NaN
# pfizer26                                 NaN                            NaN
# pfizer29                                 NaN                            NaN
# pfizer32                                 NaN                            NaN
# pfizer33                                 NaN                            NaN
# pfizer34                                 NaN                            NaN
# pfizer36                                 NaN                            NaN
# pfizer37                                 NaN                            NaN
# pfizer38                                 NaN                            NaN
# pfizer40                                 NaN                            NaN
# pfizer42                                 NaN                            NaN
# pfizer43                                 NaN                            NaN
# pfizer44                                 NaN                            NaN
# pfizer45                                 NaN                            NaN
# pfizer46                                 NaN                            NaN
# pfizer47                                 NaN                            NaN
# pfizer48                                 NaN                            NaN
# pfizer49                                 NaN                            NaN
# pfizer55                                 NaN                            NaN
# pfizer56                                 NaN                            NaN
# pfizer58                                 NaN                            NaN
# pfizer27                                 NaN                            NaN
# pfizer28                                 NaN                            NaN
# pfizer30                                 NaN                            NaN
# pfizer31                                 NaN                            NaN
# pfizer57                                 NaN                            NaN
# pfizer18                                 NaN                            NaN
# pfizer10                                 NaN                            NaN
# pfizer52                                 NaN                            NaN
# pfizer59                         66727.80898                   116916.82330
# pfizer35                                 NaN                            NaN
#
# combined_name  Gamma_RBD_Variant_IgG_boostD21  \
# participant
# pfizer00                                  NaN
# pfizer01                                  NaN
# pfizer02                                  NaN
# pfizer03                                  NaN
# pfizer04                                  NaN
# pfizer05                                  NaN
# pfizer06                                  NaN
# pfizer07                                  NaN
# pfizer08                                  NaN
# pfizer09                                  NaN
# pfizer11                                  NaN
# pfizer12                                  NaN
# pfizer13                                  NaN
# pfizer14                          35868.95167
# pfizer15                                  NaN
# pfizer16                                  NaN
# pfizer17                                  NaN
# pfizer19                                  NaN
# pfizer20                                  NaN
# pfizer22                          23020.09893
# pfizer23                                  NaN
# pfizer24                                  NaN
# pfizer25                                  NaN
# pfizer26                                  NaN
# pfizer29                                  NaN
# pfizer32                                  NaN
# pfizer33                                  NaN
# pfizer34                                  NaN
# pfizer36                                  NaN
# pfizer37                                  NaN
# pfizer38                                  NaN
# pfizer40                                  NaN
# pfizer42                                  NaN
# pfizer43                                  NaN
# pfizer44                                  NaN
# pfizer45                                  NaN
# pfizer46                                  NaN
# pfizer47                                  NaN
# pfizer48                                  NaN
# pfizer49                                  NaN
# pfizer55                                  NaN
# pfizer56                                  NaN
# pfizer58                                  NaN
# pfizer27                                  NaN
# pfizer28                                  NaN
# pfizer30                                  NaN
# pfizer31                                  NaN
# pfizer57                                  NaN
# pfizer18                                  NaN
# pfizer10                                  NaN
# pfizer52                                  NaN
# pfizer59                          92483.66907
# pfizer35                                  NaN
#
# combined_name  B.1.526.2_RBD_Variant_IgG_boostD21  \
# participant
# pfizer00                                      NaN
# pfizer01                                      NaN
# pfizer02                                      NaN
# pfizer03                                      NaN
# pfizer04                                      NaN
# pfizer05                                      NaN
# pfizer06                                      NaN
# pfizer07                                      NaN
# pfizer08                                      NaN
# pfizer09                                      NaN
# pfizer11                                      NaN
# pfizer12                                      NaN
# pfizer13                                      NaN
# pfizer14                              52287.68391
# pfizer15                                      NaN
# pfizer16                                      NaN
# pfizer17                                      NaN
# pfizer19                                      NaN
# pfizer20                                      NaN
# pfizer22                              37406.14251
# pfizer23                                      NaN
# pfizer24                                      NaN
# pfizer25                                      NaN
# pfizer26                                      NaN
# pfizer29                                      NaN
# pfizer32                                      NaN
# pfizer33                                      NaN
# pfizer34                                      NaN
# pfizer36                                      NaN
# pfizer37                                      NaN
# pfizer38                                      NaN
# pfizer40                                      NaN
# pfizer42                                      NaN
# pfizer43                                      NaN
# pfizer44                                      NaN
# pfizer45                                      NaN
# pfizer46                                      NaN
# pfizer47                                      NaN
# pfizer48                                      NaN
# pfizer49                                      NaN
# pfizer55                                      NaN
# pfizer56                                      NaN
# pfizer58                                      NaN
# pfizer27                                      NaN
# pfizer28                                      NaN
# pfizer30                                      NaN
# pfizer31                                      NaN
# pfizer57                                      NaN
# pfizer18                                      NaN
# pfizer10                                      NaN
# pfizer52                                      NaN
# pfizer59                             139787.32500
# pfizer35                                      NaN
#
# combined_name  Alpha_RBD_Variant_IgG_boostD21  P.3_RBD_Variant_IgG_boostD21  \
# participant
# pfizer00                                  NaN                           NaN
# pfizer01                                  NaN                           NaN
# pfizer02                                  NaN                           NaN
# pfizer03                                  NaN                           NaN
# pfizer04                                  NaN                           NaN
# pfizer05                                  NaN                           NaN
# pfizer06                                  NaN                           NaN
# pfizer07                                  NaN                           NaN
# pfizer08                                  NaN                           NaN
# pfizer09                                  NaN                           NaN
# pfizer11                                  NaN                           NaN
# pfizer12                                  NaN                           NaN
# pfizer13                                  NaN                           NaN
# pfizer14                          43330.68406                   29961.99131
# pfizer15                                  NaN                           NaN
# pfizer16                                  NaN                           NaN
# pfizer17                                  NaN                           NaN
# pfizer19                                  NaN                           NaN
# pfizer20                                  NaN                           NaN
# pfizer22                          35252.72997                   19617.24428
# pfizer23                                  NaN                           NaN
# pfizer24                                  NaN                           NaN
# pfizer25                                  NaN                           NaN
# pfizer26                                  NaN                           NaN
# pfizer29                                  NaN                           NaN
# pfizer32                                  NaN                           NaN
# pfizer33                                  NaN                           NaN
# pfizer34                                  NaN                           NaN
# pfizer36                                  NaN                           NaN
# pfizer37                                  NaN                           NaN
# pfizer38                                  NaN                           NaN
# pfizer40                                  NaN                           NaN
# pfizer42                                  NaN                           NaN
# pfizer43                                  NaN                           NaN
# pfizer44                                  NaN                           NaN
# pfizer45                                  NaN                           NaN
# pfizer46                                  NaN                           NaN
# pfizer47                                  NaN                           NaN
# pfizer48                                  NaN                           NaN
# pfizer49                                  NaN                           NaN
# pfizer55                                  NaN                           NaN
# pfizer56                                  NaN                           NaN
# pfizer58                                  NaN                           NaN
# pfizer27                                  NaN                           NaN
# pfizer28                                  NaN                           NaN
# pfizer30                                  NaN                           NaN
# pfizer31                                  NaN                           NaN
# pfizer57                                  NaN                           NaN
# pfizer18                                  NaN                           NaN
# pfizer10                                  NaN                           NaN
# pfizer52                                  NaN                           NaN
# pfizer59                         124842.78120                   75864.21244
# pfizer35                                  NaN                           NaN
#
# combined_name  Kappa_RBD_Variant_IgG_boostD21  Delta_RBD_Variant_IgG_boostD21  \
# participant
# pfizer00                                  NaN                             NaN
# pfizer01                                  NaN                             NaN
# pfizer02                                  NaN                             NaN
# pfizer03                                  NaN                             NaN
# pfizer04                                  NaN                             NaN
# pfizer05                                  NaN                             NaN
# pfizer06                                  NaN                             NaN
# pfizer07                                  NaN                             NaN
# pfizer08                                  NaN                             NaN
# pfizer09                                  NaN                             NaN
# pfizer11                                  NaN                             NaN
# pfizer12                                  NaN                             NaN
# pfizer13                                  NaN                             NaN
# pfizer14                          60821.29768                     44761.07318
# pfizer15                                  NaN                             NaN
# pfizer16                                  NaN                             NaN
# pfizer17                                  NaN                             NaN
# pfizer19                                  NaN                             NaN
# pfizer20                                  NaN                             NaN
# pfizer22                          36672.78384                     29069.55697
# pfizer23                                  NaN                             NaN
# pfizer24                                  NaN                             NaN
# pfizer25                                  NaN                             NaN
# pfizer26                                  NaN                             NaN
# pfizer29                                  NaN                             NaN
# pfizer32                                  NaN                             NaN
# pfizer33                                  NaN                             NaN
# pfizer34                                  NaN                             NaN
# pfizer36                                  NaN                             NaN
# pfizer37                                  NaN                             NaN
# pfizer38                                  NaN                             NaN
# pfizer40                                  NaN                             NaN
# pfizer42                                  NaN                             NaN
# pfizer43                                  NaN                             NaN
# pfizer44                                  NaN                             NaN
# pfizer45                                  NaN                             NaN
# pfizer46                                  NaN                             NaN
# pfizer47                                  NaN                             NaN
# pfizer48                                  NaN                             NaN
# pfizer49                                  NaN                             NaN
# pfizer55                                  NaN                             NaN
# pfizer56                                  NaN                             NaN
# pfizer58                                  NaN                             NaN
# pfizer27                                  NaN                             NaN
# pfizer28                                  NaN                             NaN
# pfizer30                                  NaN                             NaN
# pfizer31                                  NaN                             NaN
# pfizer57                                  NaN                             NaN
# pfizer18                                  NaN                             NaN
# pfizer10                                  NaN                             NaN
# pfizer52                                  NaN                             NaN
# pfizer59                         133355.42370                    111905.83070
# pfizer35                                  NaN                             NaN
#
# combined_name  Wuhan_RBD_Variant_IgG_boostD21
# participant
# pfizer00                                  NaN
# pfizer01                                  NaN
# pfizer02                                  NaN
# pfizer03                                  NaN
# pfizer04                                  NaN
# pfizer05                                  NaN
# pfizer06                                  NaN
# pfizer07                                  NaN
# pfizer08                                  NaN
# pfizer09                                  NaN
# pfizer11                                  NaN
# pfizer12                                  NaN
# pfizer13                                  NaN
# pfizer14                          68822.45588
# pfizer15                                  NaN
# pfizer16                                  NaN
# pfizer17                                  NaN
# pfizer19                                  NaN
# pfizer20                                  NaN
# pfizer22                          51034.19901
# pfizer23                                  NaN
# pfizer24                                  NaN
# pfizer25                                  NaN
# pfizer26                                  NaN
# pfizer29                                  NaN
# pfizer32                                  NaN
# pfizer33                                  NaN
# pfizer34                                  NaN
# pfizer36                                  NaN
# pfizer37                                  NaN
# pfizer38                                  NaN
# pfizer40                                  NaN
# pfizer42                                  NaN
# pfizer43                                  NaN
# pfizer44                                  NaN
# pfizer45                                  NaN
# pfizer46                                  NaN
# pfizer47                                  NaN
# pfizer48                                  NaN
# pfizer49                                  NaN
# pfizer55                                  NaN
# pfizer56                                  NaN
# pfizer58                                  NaN
# pfizer27                                  NaN
# pfizer28                                  NaN
# pfizer30                                  NaN
# pfizer31                                  NaN
# pfizer57                                  NaN
# pfizer18                                  NaN
# pfizer10                                  NaN
# pfizer52                                  NaN
# pfizer59                         169984.75040
# pfizer35                                  NaN
#
# [53 rows x 80 columns]

# %%
variable_info
# Out:
#                                                     virus target  \
# combined_name
# Epsilon_RBD_Variant_IgG_day 0 / pre-pandemic      Epsilon    RBD
# Beta_RBD_Variant_IgG_day 0 / pre-pandemic            Beta    RBD
# Iota_RBD_Variant_IgG_day 0 / pre-pandemic            Iota    RBD
# Gamma_RBD_Variant_IgG_day 0 / pre-pandemic          Gamma    RBD
# B.1.526.2_RBD_Variant_IgG_day 0 / pre-pandemic  B.1.526.2    RBD
# ...                                                   ...    ...
# Alpha_RBD_Variant_IgG_boostD21                      Alpha    RBD
# P.3_RBD_Variant_IgG_boostD21                          P.3    RBD
# Kappa_RBD_Variant_IgG_boostD21                      Kappa    RBD
# Delta_RBD_Variant_IgG_boostD21                      Delta    RBD
# Wuhan_RBD_Variant_IgG_boostD21                      Wuhan    RBD
#
#                                                variant_plate_type antibody  \
# combined_name
# Epsilon_RBD_Variant_IgG_day 0 / pre-pandemic              Variant      IgG
# Beta_RBD_Variant_IgG_day 0 / pre-pandemic                 Variant      IgG
# Iota_RBD_Variant_IgG_day 0 / pre-pandemic                 Variant      IgG
# Gamma_RBD_Variant_IgG_day 0 / pre-pandemic                Variant      IgG
# B.1.526.2_RBD_Variant_IgG_day 0 / pre-pandemic            Variant      IgG
# ...                                                           ...      ...
# Alpha_RBD_Variant_IgG_boostD21                            Variant      IgG
# P.3_RBD_Variant_IgG_boostD21                              Variant      IgG
# Kappa_RBD_Variant_IgG_boostD21                            Variant      IgG
# Delta_RBD_Variant_IgG_boostD21                            Variant      IgG
# Wuhan_RBD_Variant_IgG_boostD21                            Variant      IgG
#
#                                                            timepoint
# combined_name
# Epsilon_RBD_Variant_IgG_day 0 / pre-pandemic    day 0 / pre-pandemic
# Beta_RBD_Variant_IgG_day 0 / pre-pandemic       day 0 / pre-pandemic
# Iota_RBD_Variant_IgG_day 0 / pre-pandemic       day 0 / pre-pandemic
# Gamma_RBD_Variant_IgG_day 0 / pre-pandemic      day 0 / pre-pandemic
# B.1.526.2_RBD_Variant_IgG_day 0 / pre-pandemic  day 0 / pre-pandemic
# ...                                                              ...
# Alpha_RBD_Variant_IgG_boostD21                              boostD21
# P.3_RBD_Variant_IgG_boostD21                                boostD21
# Kappa_RBD_Variant_IgG_boostD21                              boostD21
# Delta_RBD_Variant_IgG_boostD21                              boostD21
# Wuhan_RBD_Variant_IgG_boostD21                              boostD21
#
# [80 rows x 5 columns]

# %%
# attach status

vaccine_participants = vaccine_participants.set_index("PID")
vaccine_participants["Status"] = "Vaccinee"
# reorder
vaccine_participants = vaccine_participants.loc[vaccine_df_pivot.index]

# confirm same order
assert_array_equal(vaccine_participants.index, vaccine_df_pivot.index)

vaccine_participants
# Out:
#             COVID Positive Ever?    Status
# participant
# pfizer00                      No  Vaccinee
# pfizer01                      No  Vaccinee
# pfizer02                      No  Vaccinee
# pfizer03                      No  Vaccinee
# pfizer04                      No  Vaccinee
# pfizer05                      No  Vaccinee
# pfizer06                      No  Vaccinee
# pfizer07                      No  Vaccinee
# pfizer08                      No  Vaccinee
# pfizer09                      No  Vaccinee
# pfizer11                      No  Vaccinee
# pfizer12                      No  Vaccinee
# pfizer13                      No  Vaccinee
# pfizer14                      No  Vaccinee
# pfizer15                     Yes  Vaccinee
# pfizer16                      No  Vaccinee
# pfizer17                      No  Vaccinee
# pfizer19                      No  Vaccinee
# pfizer20                      No  Vaccinee
# pfizer22                     Yes  Vaccinee
# pfizer23                      No  Vaccinee
# pfizer24                      No  Vaccinee
# pfizer25                     Yes  Vaccinee
# pfizer26                     NaN  Vaccinee
# pfizer29                      No  Vaccinee
# pfizer32                     Yes  Vaccinee
# pfizer33                      No  Vaccinee
# pfizer34                      No  Vaccinee
# pfizer36                      No  Vaccinee
# pfizer37                      No  Vaccinee
# pfizer38                      No  Vaccinee
# pfizer40                      No  Vaccinee
# pfizer42                      No  Vaccinee
# pfizer43                      No  Vaccinee
# pfizer44                      No  Vaccinee
# pfizer45                      No  Vaccinee
# pfizer46                      No  Vaccinee
# pfizer47                      No  Vaccinee
# pfizer48                      No  Vaccinee
# pfizer49                      No  Vaccinee
# pfizer55                      No  Vaccinee
# pfizer56                      No  Vaccinee
# pfizer58                      No  Vaccinee
# pfizer27                      No  Vaccinee
# pfizer28                      No  Vaccinee
# pfizer30                      No  Vaccinee
# pfizer31                      No  Vaccinee
# pfizer57                      No  Vaccinee
# pfizer18                      No  Vaccinee
# pfizer10                      No  Vaccinee
# pfizer52                      No  Vaccinee
# pfizer59                      No  Vaccinee
# pfizer35                      No  Vaccinee

# %%
# anndata requires string indices
vaccine_participants.index = vaccine_participants.index.astype(str)
vaccine_df_pivot.index = vaccine_df_pivot.index.astype(str)

# %%
adata_vaccine = anndata.AnnData(
    X=vaccine_df_pivot, obs=vaccine_participants, var=variable_info
)
adata_vaccine
# Out:
# AnnData object with n_obs × n_vars = 53 × 80
#     obs: 'COVID Positive Ever?', 'Status'
#     var: 'virus', 'target', 'variant_plate_type', 'antibody', 'timepoint'

# %%
adata_vaccine.var
# Out:
#                                                     virus target  \
# combined_name
# Epsilon_RBD_Variant_IgG_day 0 / pre-pandemic      Epsilon    RBD
# Beta_RBD_Variant_IgG_day 0 / pre-pandemic            Beta    RBD
# Iota_RBD_Variant_IgG_day 0 / pre-pandemic            Iota    RBD
# Gamma_RBD_Variant_IgG_day 0 / pre-pandemic          Gamma    RBD
# B.1.526.2_RBD_Variant_IgG_day 0 / pre-pandemic  B.1.526.2    RBD
# ...                                                   ...    ...
# Alpha_RBD_Variant_IgG_boostD21                      Alpha    RBD
# P.3_RBD_Variant_IgG_boostD21                          P.3    RBD
# Kappa_RBD_Variant_IgG_boostD21                      Kappa    RBD
# Delta_RBD_Variant_IgG_boostD21                      Delta    RBD
# Wuhan_RBD_Variant_IgG_boostD21                      Wuhan    RBD
#
#                                                variant_plate_type antibody  \
# combined_name
# Epsilon_RBD_Variant_IgG_day 0 / pre-pandemic              Variant      IgG
# Beta_RBD_Variant_IgG_day 0 / pre-pandemic                 Variant      IgG
# Iota_RBD_Variant_IgG_day 0 / pre-pandemic                 Variant      IgG
# Gamma_RBD_Variant_IgG_day 0 / pre-pandemic                Variant      IgG
# B.1.526.2_RBD_Variant_IgG_day 0 / pre-pandemic            Variant      IgG
# ...                                                           ...      ...
# Alpha_RBD_Variant_IgG_boostD21                            Variant      IgG
# P.3_RBD_Variant_IgG_boostD21                              Variant      IgG
# Kappa_RBD_Variant_IgG_boostD21                            Variant      IgG
# Delta_RBD_Variant_IgG_boostD21                            Variant      IgG
# Wuhan_RBD_Variant_IgG_boostD21                            Variant      IgG
#
#                                                            timepoint
# combined_name
# Epsilon_RBD_Variant_IgG_day 0 / pre-pandemic    day 0 / pre-pandemic
# Beta_RBD_Variant_IgG_day 0 / pre-pandemic       day 0 / pre-pandemic
# Iota_RBD_Variant_IgG_day 0 / pre-pandemic       day 0 / pre-pandemic
# Gamma_RBD_Variant_IgG_day 0 / pre-pandemic      day 0 / pre-pandemic
# B.1.526.2_RBD_Variant_IgG_day 0 / pre-pandemic  day 0 / pre-pandemic
# ...                                                              ...
# Alpha_RBD_Variant_IgG_boostD21                              boostD21
# P.3_RBD_Variant_IgG_boostD21                                boostD21
# Kappa_RBD_Variant_IgG_boostD21                              boostD21
# Delta_RBD_Variant_IgG_boostD21                              boostD21
# Wuhan_RBD_Variant_IgG_boostD21                              boostD21
#
# [80 rows x 5 columns]

# %%
adata_vaccine.obs["Status"].value_counts()
# Out:
# Vaccinee    53
# Name: Status, dtype: int64

# %%
adata_vaccine.write(
    f"{config.paths.generated_data_dir}/partial.pfizer_vaccine.variant_plate.h5"
)
# Out:
# ... storing 'COVID Positive Ever?' as categorical
# ... storing 'Status' as categorical
# ... storing 'virus' as categorical
# ... storing 'target' as categorical
# ... storing 'variant_plate_type' as categorical
# ... storing 'antibody' as categorical
# ... storing 'timepoint' as categorical
