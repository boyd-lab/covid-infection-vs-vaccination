# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
import pandas as pd
import seaborn as sns
import anndata
import scanpy as sc
import genetools
from covid_serology import config
from numpy.testing import assert_array_equal

# %% [markdown]
# # Load data

# %%
vaccine_participants = pd.read_csv(
    f"{config.paths.data_dir}/pfizer_demographics.csv"
).dropna(how="all")
vaccine_participants
# Out:
#          PID COVID Positive Ever?
# 0   pfizer00                   No
# 1   pfizer01                   No
# 2   pfizer02                   No
# 3   pfizer03                   No
# 4   pfizer04                   No
# 5   pfizer05                   No
# 6   pfizer06                   No
# 7   pfizer07                   No
# 8   pfizer08                   No
# 9   pfizer09                   No
# 10  pfizer10                   No
# 11  pfizer11                   No
# 12  pfizer12                   No
# 13  pfizer13                   No
# 14  pfizer14                   No
# 15  pfizer15                  Yes
# 16  pfizer16                   No
# 17  pfizer17                   No
# 18  pfizer18                   No
# 19  pfizer19                   No
# 20  pfizer20                   No
# 21  pfizer21                   No
# 22  pfizer22                  Yes
# 23  pfizer23                   No
# 24  pfizer24                   No
# 25  pfizer25                  Yes
# 26  pfizer26                  NaN
# 27  pfizer27                   No
# 28  pfizer28                   No
# 29  pfizer29                   No
# 30  pfizer30                   No
# 31  pfizer31                   No
# 32  pfizer32                  Yes
# 33  pfizer33                   No
# 34  pfizer34                   No
# 35  pfizer35                   No
# 36  pfizer36                   No
# 37  pfizer37                   No
# 38  pfizer38                   No
# 39  pfizer39                  NaN
# 40  pfizer40                   No
# 41  pfizer41                  NaN
# 42  pfizer42                   No
# 43  pfizer43                   No
# 44  pfizer44                   No
# 45  pfizer45                   No
# 46  pfizer46                   No
# 47  pfizer47                   No
# 48  pfizer48                   No
# 49  pfizer49                   No
# 50  pfizer50                   No
# 51  pfizer51                   No
# 52  pfizer52                   No
# 53  pfizer53                   No
# 54  pfizer54                   No
# 55  pfizer55                   No
# 56  pfizer56                   No
# 57  pfizer57                   No
# 58  pfizer58                   No
# 59  pfizer59                   No

# %%
vaccine_df = pd.read_csv(f"{config.paths.data_dir}/pfizer_coronavirus.csv")
vaccine_df
# Out:
#     participant  timepoint     Wuhan_S_AU     NL63_S_AU   Wuhan_N_AU  \
# 0      pfizer01  boostD1/2   13024.606820    777.295701   140.872774
# 1      pfizer01  boostD7/8  866042.530800    788.501818   210.102603
# 2      pfizer02  boostD1/2   23597.614860   1651.146945    74.422681
# 3      pfizer02  boostD7/8  593669.910400   1973.689145   121.396195
# 4      pfizer04  boostD1/2   14715.513360    909.931083    28.874592
# ..          ...        ...            ...           ...          ...
# 384    pfizer42       D210   13349.064570   3794.105836  7030.735363
# 385    pfizer43       D210    6484.640349   1763.311165    55.391124
# 386    pfizer45       D210   11866.800270   1877.302078    93.225933
# 387    pfizer46       D210    5533.840659  10226.669370   233.147245
# 388    pfizer57       D210    8196.979810   7651.388119   160.653879
#
#           CoV_S_AU  Wuhan_NTD_AU     HKU1_S_AU    OC43_S_AU   h229E_S_AU  \
# 0      2062.607562    313.991165   3945.585095  17301.86201  20378.41066
# 1    179294.543100  23268.040320  28430.056760  96357.30685  19560.92339
# 2      3383.081474    603.800822   3775.718673  22373.67391  15618.59734
# 3    125502.432300  14097.737930   8318.044619  44433.84804  17350.64436
# 4      2072.400417    237.931139  47458.355310  53553.56524  32826.84670
# ..             ...           ...           ...          ...          ...
# 384    1888.613487    317.414103  12672.472710  38933.08625  35163.20045
# 385    1212.182440    240.678884   5904.718543  16390.78487  10323.42453
# 386     973.719246    164.584676  21648.812040  64267.42992  15582.46392
# 387    1065.196248    123.362074   3523.259554  33930.91563  28372.25322
# 388    1221.485682    215.634469  11339.515120  84022.65328  57049.42333
#
#       Wuhan_RBD_AU
# 0      4690.960207
# 1    347203.782900
# 2      9726.310077
# 3    315836.125200
# 4      6096.580961
# ..             ...
# 384    5457.409734
# 385    2517.016196
# 386    4123.343836
# 387    3086.963182
# 388    3512.856333
#
# [389 rows x 11 columns]

# %%
# only one sample per patient per timepoint
assert all(vaccine_df.groupby(["participant", "timepoint"]).size() == 1)

# %% [markdown]
# # Reshape vaccine data

# %%
vaccine_df.columns
# Out:
# Index(['participant', 'timepoint', 'Wuhan_S_AU', 'NL63_S_AU', 'Wuhan_N_AU',
#        'CoV_S_AU', 'Wuhan_NTD_AU', 'HKU1_S_AU', 'OC43_S_AU', 'h229E_S_AU',
#        'Wuhan_RBD_AU'],
#       dtype='object')

# %%
vaccine_df = pd.melt(
    vaccine_df, id_vars=["participant", "timepoint"], var_name="measurement"
)
vaccine_df
# Out:
#      participant  timepoint   measurement          value
# 0       pfizer01  boostD1/2    Wuhan_S_AU   13024.606820
# 1       pfizer01  boostD7/8    Wuhan_S_AU  866042.530800
# 2       pfizer02  boostD1/2    Wuhan_S_AU   23597.614860
# 3       pfizer02  boostD7/8    Wuhan_S_AU  593669.910400
# 4       pfizer04  boostD1/2    Wuhan_S_AU   14715.513360
# ...          ...        ...           ...            ...
# 3496    pfizer42       D210  Wuhan_RBD_AU    5457.409734
# 3497    pfizer43       D210  Wuhan_RBD_AU    2517.016196
# 3498    pfizer45       D210  Wuhan_RBD_AU    4123.343836
# 3499    pfizer46       D210  Wuhan_RBD_AU    3086.963182
# 3500    pfizer57       D210  Wuhan_RBD_AU    3512.856333
#
# [3501 rows x 4 columns]

# %%
# just in case, convert to float and switch non-numeric values to nan
vaccine_df["value"] = pd.to_numeric(vaccine_df["value"], errors="coerce")
vaccine_df.dtypes
# Out:
# participant     object
# timepoint       object
# measurement     object
# value          float64
# dtype: object

# %%
vaccine_df["value"].isna().value_counts()
# Out:
# False    3498
# True        3
# Name: value, dtype: int64

# %%
vaccine_df[vaccine_df["value"].isna()]
# Out:
#      participant  timepoint   measurement  value
# 788     pfizer09  boostD1/2    Wuhan_N_AU    NaN
# 1670    pfizer17         D0  Wuhan_NTD_AU    NaN
# 2026    pfizer12         D0     HKU1_S_AU    NaN

# %%
vaccine_df["measurement"].unique()
# Out:
# array(['Wuhan_S_AU', 'NL63_S_AU', 'Wuhan_N_AU', 'CoV_S_AU',
#        'Wuhan_NTD_AU', 'HKU1_S_AU', 'OC43_S_AU', 'h229E_S_AU',
#        'Wuhan_RBD_AU'], dtype=object)

# %%
vaccine_df["measurement"] = vaccine_df["measurement"].str.replace("_AU", "")
vaccine_df["measurement"].value_counts()
# Out:
# Wuhan_RBD    389
# NL63_S       389
# Wuhan_S      389
# h229E_S      389
# Wuhan_NTD    389
# Wuhan_N      389
# OC43_S       389
# CoV_S        389
# HKU1_S       389
# Name: measurement, dtype: int64

# %%
# extract parts of measurement column
# all coronavirus plate measurements are IgG only
measurement_parts = (
    vaccine_df["measurement"]
    .str.split("_", expand=True)
    .rename(columns={0: "virus", 1: "target"})
    .assign(variant_plate_type="Wuhan", antibody="IgG")
    .apply(lambda col: col.str.strip())
)
measurement_parts
# Out:
#       virus target variant_plate_type antibody
# 0     Wuhan      S              Wuhan      IgG
# 1     Wuhan      S              Wuhan      IgG
# 2     Wuhan      S              Wuhan      IgG
# 3     Wuhan      S              Wuhan      IgG
# 4     Wuhan      S              Wuhan      IgG
# ...     ...    ...                ...      ...
# 3496  Wuhan    RBD              Wuhan      IgG
# 3497  Wuhan    RBD              Wuhan      IgG
# 3498  Wuhan    RBD              Wuhan      IgG
# 3499  Wuhan    RBD              Wuhan      IgG
# 3500  Wuhan    RBD              Wuhan      IgG
#
# [3501 rows x 4 columns]

# %%
measurement_parts["virus"].value_counts()
# Out:
# Wuhan    1556
# h229E     389
# CoV       389
# OC43      389
# NL63      389
# HKU1      389
# Name: virus, dtype: int64

# %%
measurement_parts["target"].value_counts()
# Out:
# S      2334
# NTD     389
# RBD     389
# N       389
# Name: target, dtype: int64

# %%
measurement_parts["variant_plate_type"].value_counts()
# Out:
# Wuhan    3501
# Name: variant_plate_type, dtype: int64

# %%
vaccine_df = pd.concat([vaccine_df, measurement_parts], axis=1)
vaccine_df
# Out:
#      participant  timepoint measurement          value  virus target  \
# 0       pfizer01  boostD1/2     Wuhan_S   13024.606820  Wuhan      S
# 1       pfizer01  boostD7/8     Wuhan_S  866042.530800  Wuhan      S
# 2       pfizer02  boostD1/2     Wuhan_S   23597.614860  Wuhan      S
# 3       pfizer02  boostD7/8     Wuhan_S  593669.910400  Wuhan      S
# 4       pfizer04  boostD1/2     Wuhan_S   14715.513360  Wuhan      S
# ...          ...        ...         ...            ...    ...    ...
# 3496    pfizer42       D210   Wuhan_RBD    5457.409734  Wuhan    RBD
# 3497    pfizer43       D210   Wuhan_RBD    2517.016196  Wuhan    RBD
# 3498    pfizer45       D210   Wuhan_RBD    4123.343836  Wuhan    RBD
# 3499    pfizer46       D210   Wuhan_RBD    3086.963182  Wuhan    RBD
# 3500    pfizer57       D210   Wuhan_RBD    3512.856333  Wuhan    RBD
#
#      variant_plate_type antibody
# 0                 Wuhan      IgG
# 1                 Wuhan      IgG
# 2                 Wuhan      IgG
# 3                 Wuhan      IgG
# 4                 Wuhan      IgG
# ...                 ...      ...
# 3496              Wuhan      IgG
# 3497              Wuhan      IgG
# 3498              Wuhan      IgG
# 3499              Wuhan      IgG
# 3500              Wuhan      IgG
#
# [3501 rows x 8 columns]

# %%
vaccine_df["timepoint"].value_counts()
# Out:
# D21          531
# D0           522
# D42          495
# D28          468
# D7           441
# D90          369
# D210         315
# boostD1/2    198
# boostD7/8    135
# boostD21      27
# Name: timepoint, dtype: int64

# %%
# timepoint label map
map_vaccine_to_global_timepoint_labels = {
    "D0": "day 0 / pre-pandemic",
    "D7": "day 7 / week 1",
    "D21": "day 21 / weeks 2&3",
    "D28": "day 28 / week 4",
    "D42": "day 42 / weeks 5&6",
    "D90": "week 7 and later / 3 months",
    "D210": "day 210 / 7 months",
    "boostD1/2": "boostD1/2",
    "boostD7/8": "boostD7/8",
    "boostD21": "boostD21",
}
assert all(
    tp in map_vaccine_to_global_timepoint_labels.keys()
    for tp in vaccine_df["timepoint"].unique()
)

# %%
def process_vaccine_timepoint(df_partial, timepoint):
    # at a given time point: only one measurement per patient-virus-target combo
    assert all(
        df_partial.groupby(
            ["participant", "virus", "target", "variant_plate_type", "antibody"]
        ).size()
        == 1
    )

    # unmelt
    vaccine_df_pivot = pd.pivot(
        df_partial,
        index="participant",
        columns=[
            "virus",
            "target",
            "variant_plate_type",
            "antibody",
        ],
        values="value",
    )

    ## set column names
    variable_info = vaccine_df_pivot.columns.to_frame().reset_index(drop=True)
    # create combined name
    variable_info["timepoint"] = timepoint
    variable_info["combined_name"] = variable_info.apply("_".join, axis=1)
    variable_info = variable_info.set_index("combined_name")

    # set var names
    vaccine_df_pivot.columns = variable_info.index.copy()

    # drop patients with any NaNs in this timepoint
    vaccine_df_pivot = vaccine_df_pivot.dropna(how="any")
    assert not vaccine_df_pivot.isna().any().any()

    return vaccine_df_pivot, variable_info

# %%
X_partial = []
var_partial = []
for vaccine_timepoint in vaccine_df["timepoint"].unique():
    associated_global_timepoint_label = map_vaccine_to_global_timepoint_labels[
        vaccine_timepoint
    ]
    print(vaccine_timepoint, "->", associated_global_timepoint_label)
    df_partial = vaccine_df[vaccine_df["timepoint"] == vaccine_timepoint]
    vaccine_df_pivot, variable_info = process_vaccine_timepoint(
        df_partial, associated_global_timepoint_label
    )
    X_partial.append(vaccine_df_pivot)
    var_partial.append(variable_info)
vaccine_df_pivot = pd.concat(X_partial, axis=1)
variable_info = pd.concat(var_partial, axis=0)
# Out:
# boostD1/2 -> boostD1/2
# boostD7/8 -> boostD7/8
# boostD21 -> boostD21
# D0 -> day 0 / pre-pandemic
# D7 -> day 7 / week 1
# D42 -> day 42 / weeks 5&6
# D21 -> day 21 / weeks 2&3
# D28 -> day 28 / week 4
# D90 -> week 7 and later / 3 months
# D210 -> day 210 / 7 months

# %%
# note: there are NaNs - patients don't have entries for all timepoints
vaccine_df_pivot
# Out:
# combined_name  Wuhan_S_Wuhan_IgG_boostD1/2  NL63_S_Wuhan_IgG_boostD1/2  \
# participant
# pfizer01                      13024.606820                  777.295701
# pfizer02                      23597.614860                 1651.146945
# pfizer04                      14715.513360                  909.931083
# pfizer06                      11603.955800                 1764.573828
# pfizer07                      10262.012860                  810.933733
# pfizer10                      12664.526310                 2961.836655
# pfizer13                      10290.097200                 3588.562709
# pfizer14                       2303.834527                 1508.092936
# pfizer24                       2122.167958                 3426.351197
# pfizer26                      11618.835090                 1628.037640
# pfizer28                      17615.657510                 9647.302571
# pfizer37                      12231.740800                 2477.437094
# pfizer42                       8574.561536                 3402.523379
# pfizer43                       2398.248711                 1300.875537
# pfizer48                       6182.388587                 1303.736717
# pfizer52                       5566.091022                 3858.198258
# pfizer55                      21761.040380                 2743.676639
# pfizer56                      20089.086610                 2915.071949
# pfizer57                       3186.023146                 5315.129714
# pfizer58                      21813.595900                 1835.911433
# pfizer59                       8706.033120                 1714.766373
# pfizer05                               NaN                         NaN
# pfizer15                               NaN                         NaN
# pfizer27                               NaN                         NaN
# pfizer35                               NaN                         NaN
# pfizer22                               NaN                         NaN
# pfizer00                               NaN                         NaN
# pfizer03                               NaN                         NaN
# pfizer08                               NaN                         NaN
# pfizer09                               NaN                         NaN
# pfizer11                               NaN                         NaN
# pfizer16                               NaN                         NaN
# pfizer18                               NaN                         NaN
# pfizer19                               NaN                         NaN
# pfizer20                               NaN                         NaN
# pfizer21                               NaN                         NaN
# pfizer23                               NaN                         NaN
# pfizer25                               NaN                         NaN
# pfizer29                               NaN                         NaN
# pfizer30                               NaN                         NaN
# pfizer31                               NaN                         NaN
# pfizer32                               NaN                         NaN
# pfizer33                               NaN                         NaN
# pfizer34                               NaN                         NaN
# pfizer36                               NaN                         NaN
# pfizer38                               NaN                         NaN
# pfizer39                               NaN                         NaN
# pfizer40                               NaN                         NaN
# pfizer41                               NaN                         NaN
# pfizer44                               NaN                         NaN
# pfizer45                               NaN                         NaN
# pfizer46                               NaN                         NaN
# pfizer47                               NaN                         NaN
# pfizer49                               NaN                         NaN
# pfizer50                               NaN                         NaN
# pfizer51                               NaN                         NaN
# pfizer53                               NaN                         NaN
# pfizer54                               NaN                         NaN
# pfizer12                               NaN                         NaN
# pfizer17                               NaN                         NaN
#
# combined_name  Wuhan_N_Wuhan_IgG_boostD1/2  CoV_S_Wuhan_IgG_boostD1/2  \
# participant
# pfizer01                        140.872774                2062.607562
# pfizer02                         74.422681                3383.081474
# pfizer04                         28.874592                2072.400417
# pfizer06                         42.927934                2007.127267
# pfizer07                         56.994180                1628.356167
# pfizer10                         25.531058                4149.336191
# pfizer13                         89.178828                1594.202103
# pfizer14                        226.243773                 758.169351
# pfizer24                         70.399613                 110.238726
# pfizer26                         52.304235                1160.945445
# pfizer28                        332.577102                2652.069723
# pfizer37                         67.047538                1737.390781
# pfizer42                       4585.128954                1433.333399
# pfizer43                         49.624780                 507.005246
# pfizer48                       1783.130311                1733.320544
# pfizer52                         24.862490                 681.791348
# pfizer55                         31.550194                4086.703379
# pfizer56                        654.762384                2516.990685
# pfizer57                         73.081590                 775.067984
# pfizer58                          6.837171                2012.837479
# pfizer59                         10.169973                1553.556029
# pfizer05                               NaN                        NaN
# pfizer15                               NaN                        NaN
# pfizer27                               NaN                        NaN
# pfizer35                               NaN                        NaN
# pfizer22                               NaN                        NaN
# pfizer00                               NaN                        NaN
# pfizer03                               NaN                        NaN
# pfizer08                               NaN                        NaN
# pfizer09                               NaN                        NaN
# pfizer11                               NaN                        NaN
# pfizer16                               NaN                        NaN
# pfizer18                               NaN                        NaN
# pfizer19                               NaN                        NaN
# pfizer20                               NaN                        NaN
# pfizer21                               NaN                        NaN
# pfizer23                               NaN                        NaN
# pfizer25                               NaN                        NaN
# pfizer29                               NaN                        NaN
# pfizer30                               NaN                        NaN
# pfizer31                               NaN                        NaN
# pfizer32                               NaN                        NaN
# pfizer33                               NaN                        NaN
# pfizer34                               NaN                        NaN
# pfizer36                               NaN                        NaN
# pfizer38                               NaN                        NaN
# pfizer39                               NaN                        NaN
# pfizer40                               NaN                        NaN
# pfizer41                               NaN                        NaN
# pfizer44                               NaN                        NaN
# pfizer45                               NaN                        NaN
# pfizer46                               NaN                        NaN
# pfizer47                               NaN                        NaN
# pfizer49                               NaN                        NaN
# pfizer50                               NaN                        NaN
# pfizer51                               NaN                        NaN
# pfizer53                               NaN                        NaN
# pfizer54                               NaN                        NaN
# pfizer12                               NaN                        NaN
# pfizer17                               NaN                        NaN
#
# combined_name  Wuhan_NTD_Wuhan_IgG_boostD1/2  HKU1_S_Wuhan_IgG_boostD1/2  \
# participant
# pfizer01                          313.991165                 3945.585095
# pfizer02                          603.800822                 3775.718673
# pfizer04                          237.931139                47458.355310
# pfizer06                          355.211225                 5432.205784
# pfizer07                          269.130474                 8037.521706
# pfizer10                          268.473446                 9079.018693
# pfizer13                          245.756464                12742.101100
# pfizer14                           65.040360                 3732.511087
# pfizer24                           14.637253                 4336.915468
# pfizer26                          225.840074                 4619.505684
# pfizer28                          498.232448                16915.217500
# pfizer37                          273.894173                10475.955400
# pfizer42                          177.073999                 9467.023385
# pfizer43                           75.806942                 3575.573980
# pfizer48                          122.978384                15628.346440
# pfizer52                          144.364252                12264.566120
# pfizer55                          531.358848                11536.767940
# pfizer56                          625.850397                 3851.199491
# pfizer57                           78.853512                 7222.804023
# pfizer58                          498.726790                 7755.315588
# pfizer59                          220.588873                27300.430550
# pfizer05                                 NaN                         NaN
# pfizer15                                 NaN                         NaN
# pfizer27                                 NaN                         NaN
# pfizer35                                 NaN                         NaN
# pfizer22                                 NaN                         NaN
# pfizer00                                 NaN                         NaN
# pfizer03                                 NaN                         NaN
# pfizer08                                 NaN                         NaN
# pfizer09                                 NaN                         NaN
# pfizer11                                 NaN                         NaN
# pfizer16                                 NaN                         NaN
# pfizer18                                 NaN                         NaN
# pfizer19                                 NaN                         NaN
# pfizer20                                 NaN                         NaN
# pfizer21                                 NaN                         NaN
# pfizer23                                 NaN                         NaN
# pfizer25                                 NaN                         NaN
# pfizer29                                 NaN                         NaN
# pfizer30                                 NaN                         NaN
# pfizer31                                 NaN                         NaN
# pfizer32                                 NaN                         NaN
# pfizer33                                 NaN                         NaN
# pfizer34                                 NaN                         NaN
# pfizer36                                 NaN                         NaN
# pfizer38                                 NaN                         NaN
# pfizer39                                 NaN                         NaN
# pfizer40                                 NaN                         NaN
# pfizer41                                 NaN                         NaN
# pfizer44                                 NaN                         NaN
# pfizer45                                 NaN                         NaN
# pfizer46                                 NaN                         NaN
# pfizer47                                 NaN                         NaN
# pfizer49                                 NaN                         NaN
# pfizer50                                 NaN                         NaN
# pfizer51                                 NaN                         NaN
# pfizer53                                 NaN                         NaN
# pfizer54                                 NaN                         NaN
# pfizer12                                 NaN                         NaN
# pfizer17                                 NaN                         NaN
#
# combined_name  OC43_S_Wuhan_IgG_boostD1/2  h229E_S_Wuhan_IgG_boostD1/2  \
# participant
# pfizer01                     17301.862010                 20378.410660
# pfizer02                     22373.673910                 15618.597340
# pfizer04                     53553.565240                 32826.846700
# pfizer06                     26171.722560                 14369.256050
# pfizer07                     19109.724860                 34683.205570
# pfizer10                     32259.943280                 37747.776990
# pfizer13                     23365.704410                 13495.273090
# pfizer14                     24216.543120                  3301.944167
# pfizer24                     14114.472010                  7364.154416
# pfizer26                     19590.192780                 15947.235480
# pfizer28                     36597.893050                 37455.309210
# pfizer37                     26353.464480                 13231.325180
# pfizer42                     27806.936500                 35483.160120
# pfizer43                      9510.065746                  7627.187062
# pfizer48                     48055.364120                  8691.598944
# pfizer52                      3753.456786                 26944.309400
# pfizer55                     31147.410640                 24526.951190
# pfizer56                     18151.590270                 15535.266260
# pfizer57                     60636.350650                 32208.038090
# pfizer58                     30478.785390                  6407.672195
# pfizer59                     96706.313980                 18977.448740
# pfizer05                              NaN                          NaN
# pfizer15                              NaN                          NaN
# pfizer27                              NaN                          NaN
# pfizer35                              NaN                          NaN
# pfizer22                              NaN                          NaN
# pfizer00                              NaN                          NaN
# pfizer03                              NaN                          NaN
# pfizer08                              NaN                          NaN
# pfizer09                              NaN                          NaN
# pfizer11                              NaN                          NaN
# pfizer16                              NaN                          NaN
# pfizer18                              NaN                          NaN
# pfizer19                              NaN                          NaN
# pfizer20                              NaN                          NaN
# pfizer21                              NaN                          NaN
# pfizer23                              NaN                          NaN
# pfizer25                              NaN                          NaN
# pfizer29                              NaN                          NaN
# pfizer30                              NaN                          NaN
# pfizer31                              NaN                          NaN
# pfizer32                              NaN                          NaN
# pfizer33                              NaN                          NaN
# pfizer34                              NaN                          NaN
# pfizer36                              NaN                          NaN
# pfizer38                              NaN                          NaN
# pfizer39                              NaN                          NaN
# pfizer40                              NaN                          NaN
# pfizer41                              NaN                          NaN
# pfizer44                              NaN                          NaN
# pfizer45                              NaN                          NaN
# pfizer46                              NaN                          NaN
# pfizer47                              NaN                          NaN
# pfizer49                              NaN                          NaN
# pfizer50                              NaN                          NaN
# pfizer51                              NaN                          NaN
# pfizer53                              NaN                          NaN
# pfizer54                              NaN                          NaN
# pfizer12                              NaN                          NaN
# pfizer17                              NaN                          NaN
#
# combined_name  Wuhan_RBD_Wuhan_IgG_boostD1/2  Wuhan_S_Wuhan_IgG_boostD7/8  \
# participant
# pfizer01                         4690.960207                 866042.53080
# pfizer02                         9726.310077                 593669.91040
# pfizer04                         6096.580961                 494663.93640
# pfizer06                         4542.135836                 633563.77260
# pfizer07                         3830.727360                          NaN
# pfizer10                         5766.672416                 324339.25810
# pfizer13                         4532.835995                 312964.68320
# pfizer14                         1276.576739                 193319.88210
# pfizer24                          632.835109                  89363.01321
# pfizer26                         4391.038478                          NaN
# pfizer28                         6685.163978                          NaN
# pfizer37                         4470.648477                          NaN
# pfizer42                         3316.462359                          NaN
# pfizer43                          862.682663                 289147.34010
# pfizer48                         2239.243154                          NaN
# pfizer52                         2849.882790                 197633.99810
# pfizer55                         8954.984531                 269120.48110
# pfizer56                         6564.951460                          NaN
# pfizer57                         1294.932244                          NaN
# pfizer58                         7459.487070                          NaN
# pfizer59                         3132.868555                          NaN
# pfizer05                                 NaN                 719950.53670
# pfizer15                                 NaN                 325651.63790
# pfizer27                                 NaN                 394224.35840
# pfizer35                                 NaN                  35562.48586
# pfizer22                                 NaN                          NaN
# pfizer00                                 NaN                          NaN
# pfizer03                                 NaN                          NaN
# pfizer08                                 NaN                          NaN
# pfizer09                                 NaN                          NaN
# pfizer11                                 NaN                          NaN
# pfizer16                                 NaN                          NaN
# pfizer18                                 NaN                          NaN
# pfizer19                                 NaN                          NaN
# pfizer20                                 NaN                          NaN
# pfizer21                                 NaN                          NaN
# pfizer23                                 NaN                          NaN
# pfizer25                                 NaN                          NaN
# pfizer29                                 NaN                          NaN
# pfizer30                                 NaN                          NaN
# pfizer31                                 NaN                          NaN
# pfizer32                                 NaN                          NaN
# pfizer33                                 NaN                          NaN
# pfizer34                                 NaN                          NaN
# pfizer36                                 NaN                          NaN
# pfizer38                                 NaN                          NaN
# pfizer39                                 NaN                          NaN
# pfizer40                                 NaN                          NaN
# pfizer41                                 NaN                          NaN
# pfizer44                                 NaN                          NaN
# pfizer45                                 NaN                          NaN
# pfizer46                                 NaN                          NaN
# pfizer47                                 NaN                          NaN
# pfizer49                                 NaN                          NaN
# pfizer50                                 NaN                          NaN
# pfizer51                                 NaN                          NaN
# pfizer53                                 NaN                          NaN
# pfizer54                                 NaN                          NaN
# pfizer12                                 NaN                          NaN
# pfizer17                                 NaN                          NaN
#
# combined_name  ...  Wuhan_RBD_Wuhan_IgG_week 7 and later / 3 months  \
# participant    ...
# pfizer01       ...                                       35663.9485
# pfizer02       ...                                       62742.4345
# pfizer04       ...                                       68891.2145
# pfizer06       ...                                       30695.5805
# pfizer07       ...                                       10148.5595
# pfizer10       ...                                              NaN
# pfizer13       ...                                       19486.7850
# pfizer14       ...                                              NaN
# pfizer24       ...                                              NaN
# pfizer26       ...                                              NaN
# pfizer28       ...                                       56297.7285
# pfizer37       ...                                              NaN
# pfizer42       ...                                       21293.9100
# pfizer43       ...                                        6061.6435
# pfizer48       ...                                       28930.2980
# pfizer52       ...                                       21569.8955
# pfizer55       ...                                       44556.9345
# pfizer56       ...                                       63143.0240
# pfizer57       ...                                       23395.7685
# pfizer58       ...                                       77070.7495
# pfizer59       ...                                              NaN
# pfizer05       ...                                              NaN
# pfizer15       ...                                      127841.2975
# pfizer27       ...                                       12546.4245
# pfizer35       ...                                              NaN
# pfizer22       ...                                       10795.5705
# pfizer00       ...                                       84854.6165
# pfizer03       ...                                              NaN
# pfizer08       ...                                       14700.6265
# pfizer09       ...                                       14776.1375
# pfizer11       ...                                       37419.0450
# pfizer16       ...                                              NaN
# pfizer18       ...                                       23937.4720
# pfizer19       ...                                              NaN
# pfizer20       ...                                       13521.7175
# pfizer21       ...                                              NaN
# pfizer23       ...                                              NaN
# pfizer25       ...                                       65316.9005
# pfizer29       ...                                       19298.1370
# pfizer30       ...                                       32063.4945
# pfizer31       ...                                        8483.9105
# pfizer32       ...                                       14852.3895
# pfizer33       ...                                              NaN
# pfizer34       ...                                       35732.0375
# pfizer36       ...                                              NaN
# pfizer38       ...                                              NaN
# pfizer39       ...                                              NaN
# pfizer40       ...                                       13890.4745
# pfizer41       ...                                              NaN
# pfizer44       ...                                       61603.8465
# pfizer45       ...                                       16120.3540
# pfizer46       ...                                       14359.5115
# pfizer47       ...                                       27925.7550
# pfizer49       ...                                       22722.7655
# pfizer50       ...                                       42546.9435
# pfizer51       ...                                              NaN
# pfizer53       ...                                       25301.8925
# pfizer54       ...                                       10843.6975
# pfizer12       ...                                       17981.2095
# pfizer17       ...                                       51306.6895
#
# combined_name  Wuhan_S_Wuhan_IgG_day 210 / 7 months  \
# participant
# pfizer01                                        NaN
# pfizer02                                        NaN
# pfizer04                               46368.355820
# pfizer06                               25890.354440
# pfizer07                               12371.468540
# pfizer10                               18609.208000
# pfizer13                               18424.632010
# pfizer14                                4430.975699
# pfizer24                                3379.426000
# pfizer26                                        NaN
# pfizer28                               25130.194820
# pfizer37                               16914.441960
# pfizer42                               13349.064570
# pfizer43                                6484.640349
# pfizer48                                        NaN
# pfizer52                                        NaN
# pfizer55                                        NaN
# pfizer56                               30040.345510
# pfizer57                                8196.979810
# pfizer58                               47711.471450
# pfizer59                                        NaN
# pfizer05                               20692.146520
# pfizer15                              211287.515500
# pfizer27                                        NaN
# pfizer35                                        NaN
# pfizer22                               14395.601010
# pfizer00                               49446.603370
# pfizer03                                7317.577777
# pfizer08                                        NaN
# pfizer09                               10858.671990
# pfizer11                                        NaN
# pfizer16                                        NaN
# pfizer18                               24479.592160
# pfizer19                               14351.862070
# pfizer20                               14373.423600
# pfizer21                                        NaN
# pfizer23                               15087.019230
# pfizer25                               80018.642100
# pfizer29                               17373.906860
# pfizer30                               30438.673450
# pfizer31                                        NaN
# pfizer32                                8889.094446
# pfizer33                                6912.613665
# pfizer34                               25316.022000
# pfizer36                               10468.123350
# pfizer38                               10130.575000
# pfizer39                                        NaN
# pfizer40                                        NaN
# pfizer41                                        NaN
# pfizer44                                        NaN
# pfizer45                               11866.800270
# pfizer46                                5533.840659
# pfizer47                                        NaN
# pfizer49                                        NaN
# pfizer50                                        NaN
# pfizer51                                        NaN
# pfizer53                                        NaN
# pfizer54                                        NaN
# pfizer12                                        NaN
# pfizer17                               51681.924930
#
# combined_name  NL63_S_Wuhan_IgG_day 210 / 7 months  \
# participant
# pfizer01                                       NaN
# pfizer02                                       NaN
# pfizer04                               1035.028782
# pfizer06                               2885.216385
# pfizer07                                832.362203
# pfizer10                               3218.789626
# pfizer13                               4192.094816
# pfizer14                               2621.168447
# pfizer24                               4681.743307
# pfizer26                                       NaN
# pfizer28                               9962.565015
# pfizer37                               2624.304156
# pfizer42                               3794.105836
# pfizer43                               1763.311165
# pfizer48                                       NaN
# pfizer52                                       NaN
# pfizer55                                       NaN
# pfizer56                               3147.037803
# pfizer57                               7651.388119
# pfizer58                               2164.708013
# pfizer59                                       NaN
# pfizer05                               2825.518287
# pfizer15                               4014.977420
# pfizer27                                       NaN
# pfizer35                                       NaN
# pfizer22                               7454.160878
# pfizer00                               6495.961778
# pfizer03                               3936.161267
# pfizer08                                       NaN
# pfizer09                                686.170834
# pfizer11                                       NaN
# pfizer16                                       NaN
# pfizer18                               8387.045192
# pfizer19                               1586.110504
# pfizer20                               1791.965729
# pfizer21                                       NaN
# pfizer23                               3178.533890
# pfizer25                               5966.405371
# pfizer29                               2859.029381
# pfizer30                               6455.380449
# pfizer31                                       NaN
# pfizer32                               3287.076508
# pfizer33                               2187.602264
# pfizer34                               6200.642585
# pfizer36                               5265.047624
# pfizer38                               1027.189188
# pfizer39                                       NaN
# pfizer40                                       NaN
# pfizer41                                       NaN
# pfizer44                                       NaN
# pfizer45                               1877.302078
# pfizer46                              10226.669370
# pfizer47                                       NaN
# pfizer49                                       NaN
# pfizer50                                       NaN
# pfizer51                                       NaN
# pfizer53                                       NaN
# pfizer54                                       NaN
# pfizer12                                       NaN
# pfizer17                               1841.359621
#
# combined_name  Wuhan_N_Wuhan_IgG_day 210 / 7 months  \
# participant
# pfizer01                                        NaN
# pfizer02                                        NaN
# pfizer04                                  30.930252
# pfizer06                                  76.399471
# pfizer07                                  69.743534
# pfizer10                                  56.790667
# pfizer13                                 105.153348
# pfizer14                                 410.553630
# pfizer24                                 115.682757
# pfizer26                                        NaN
# pfizer28                                 469.542398
# pfizer37                                  50.144323
# pfizer42                                7030.735363
# pfizer43                                  55.391124
# pfizer48                                        NaN
# pfizer52                                        NaN
# pfizer55                                        NaN
# pfizer56                                 693.416724
# pfizer57                                 160.653879
# pfizer58                                  29.534694
# pfizer59                                        NaN
# pfizer05                                  46.647848
# pfizer15                                 969.029996
# pfizer27                                        NaN
# pfizer35                                        NaN
# pfizer22                                 377.720231
# pfizer00                                 789.371875
# pfizer03                                  58.540320
# pfizer08                                        NaN
# pfizer09                                  30.930252
# pfizer11                                        NaN
# pfizer16                                        NaN
# pfizer18                                  67.642255
# pfizer19                                 627.947055
# pfizer20                                  38.610708
# pfizer21                                        NaN
# pfizer23                                 171.906493
# pfizer25                                5917.727087
# pfizer29                                 332.199215
# pfizer30                                 217.653168
# pfizer31                                        NaN
# pfizer32                                  62.390396
# pfizer33                                 107.960734
# pfizer34                                 192.662265
# pfizer36                                  54.691413
# pfizer38                                  31.977113
# pfizer39                                        NaN
# pfizer40                                        NaN
# pfizer41                                        NaN
# pfizer44                                        NaN
# pfizer45                                  93.225933
# pfizer46                                 233.147245
# pfizer47                                        NaN
# pfizer49                                        NaN
# pfizer50                                        NaN
# pfizer51                                        NaN
# pfizer53                                        NaN
# pfizer54                                        NaN
# pfizer12                                        NaN
# pfizer17                                  65.541277
#
# combined_name  CoV_S_Wuhan_IgG_day 210 / 7 months  \
# participant
# pfizer01                                      NaN
# pfizer02                                      NaN
# pfizer04                              4023.564051
# pfizer06                              3080.216325
# pfizer07                              1615.378625
# pfizer10                              5963.678024
# pfizer13                              2286.500366
# pfizer14                              1133.156750
# pfizer24                               210.723368
# pfizer26                                      NaN
# pfizer28                              3003.284522
# pfizer37                              2147.173828
# pfizer42                              1888.613487
# pfizer43                              1212.182440
# pfizer48                                      NaN
# pfizer52                                      NaN
# pfizer55                                      NaN
# pfizer56                              3098.272335
# pfizer57                              1221.485682
# pfizer58                              3581.286580
# pfizer59                                      NaN
# pfizer05                              6882.239131
# pfizer15                             17966.644280
# pfizer27                                      NaN
# pfizer35                                      NaN
# pfizer22                              2096.781657
# pfizer00                              7221.228130
# pfizer03                               978.774048
# pfizer08                                      NaN
# pfizer09                              1567.791511
# pfizer11                                      NaN
# pfizer16                                      NaN
# pfizer18                              6618.496719
# pfizer19                              2070.312972
# pfizer20                              1460.390749
# pfizer21                                      NaN
# pfizer23                              1876.255191
# pfizer25                             10070.730870
# pfizer29                              1490.941616
# pfizer30                              4864.698818
# pfizer31                                      NaN
# pfizer32                               475.264402
# pfizer33                              1273.522066
# pfizer34                              4021.404418
# pfizer36                              1474.391842
# pfizer38                              1666.392318
# pfizer39                                      NaN
# pfizer40                                      NaN
# pfizer41                                      NaN
# pfizer44                                      NaN
# pfizer45                               973.719246
# pfizer46                              1065.196248
# pfizer47                                      NaN
# pfizer49                                      NaN
# pfizer50                                      NaN
# pfizer51                                      NaN
# pfizer53                                      NaN
# pfizer54                                      NaN
# pfizer12                                      NaN
# pfizer17                              5941.060250
#
# combined_name  Wuhan_NTD_Wuhan_IgG_day 210 / 7 months  \
# participant
# pfizer01                                          NaN
# pfizer02                                          NaN
# pfizer04                                   748.478920
# pfizer06                                   755.766165
# pfizer07                                   355.511280
# pfizer10                                   395.003098
# pfizer13                                   483.946814
# pfizer14                                   134.775728
# pfizer24                                    40.717480
# pfizer26                                          NaN
# pfizer28                                   728.227086
# pfizer37                                   402.759742
# pfizer42                                   317.414103
# pfizer43                                   240.678884
# pfizer48                                          NaN
# pfizer52                                          NaN
# pfizer55                                          NaN
# pfizer56                                  1059.340671
# pfizer57                                   215.634469
# pfizer58                                  1156.476633
# pfizer59                                          NaN
# pfizer05                                   700.668912
# pfizer15                                  2386.900399
# pfizer27                                          NaN
# pfizer35                                          NaN
# pfizer22                                   277.749707
# pfizer00                                  1252.121937
# pfizer03                                   153.387248
# pfizer08                                          NaN
# pfizer09                                   191.382713
# pfizer11                                          NaN
# pfizer16                                          NaN
# pfizer18                                   496.668915
# pfizer19                                   374.194385
# pfizer20                                   268.804637
# pfizer21                                          NaN
# pfizer23                                   563.471871
# pfizer25                                  1288.092380
# pfizer29                                   280.497991
# pfizer30                                   847.972760
# pfizer31                                          NaN
# pfizer32                                   234.521598
# pfizer33                                   139.986652
# pfizer34                                   557.501336
# pfizer36                                   266.362870
# pfizer38                                   226.263923
# pfizer39                                          NaN
# pfizer40                                          NaN
# pfizer41                                          NaN
# pfizer44                                          NaN
# pfizer45                                   164.584676
# pfizer46                                   123.362074
# pfizer47                                          NaN
# pfizer49                                          NaN
# pfizer50                                          NaN
# pfizer51                                          NaN
# pfizer53                                          NaN
# pfizer54                                          NaN
# pfizer12                                          NaN
# pfizer17                                  1629.973320
#
# combined_name  HKU1_S_Wuhan_IgG_day 210 / 7 months  \
# participant
# pfizer01                                       NaN
# pfizer02                                       NaN
# pfizer04                              53666.420360
# pfizer06                               7595.767357
# pfizer07                               7814.370600
# pfizer10                               9087.051591
# pfizer13                              11078.780550
# pfizer14                               5751.972822
# pfizer24                               5870.636559
# pfizer26                                       NaN
# pfizer28                              15547.383320
# pfizer37                              11769.049090
# pfizer42                              12672.472710
# pfizer43                               5904.718543
# pfizer48                                       NaN
# pfizer52                                       NaN
# pfizer55                                       NaN
# pfizer56                               4096.476774
# pfizer57                              11339.515120
# pfizer58                               9038.879319
# pfizer59                                       NaN
# pfizer05                              68766.186560
# pfizer15                              24698.157830
# pfizer27                                       NaN
# pfizer35                                       NaN
# pfizer22                              14386.864570
# pfizer00                              19988.721360
# pfizer03                               3214.556665
# pfizer08                                       NaN
# pfizer09                               8474.979913
# pfizer11                                       NaN
# pfizer16                                       NaN
# pfizer18                              10723.944770
# pfizer19                               5087.977865
# pfizer20                              34226.083210
# pfizer21                                       NaN
# pfizer23                               4448.606579
# pfizer25                              37206.395050
# pfizer29                               9892.129982
# pfizer30                              18775.989950
# pfizer31                                       NaN
# pfizer32                               1212.224391
# pfizer33                               6624.449774
# pfizer34                               8896.193679
# pfizer36                               8656.361722
# pfizer38                               6121.243138
# pfizer39                                       NaN
# pfizer40                                       NaN
# pfizer41                                       NaN
# pfizer44                                       NaN
# pfizer45                              21648.812040
# pfizer46                               3523.259554
# pfizer47                                       NaN
# pfizer49                                       NaN
# pfizer50                                       NaN
# pfizer51                                       NaN
# pfizer53                                       NaN
# pfizer54                                       NaN
# pfizer12                                       NaN
# pfizer17                              46550.611300
#
# combined_name  OC43_S_Wuhan_IgG_day 210 / 7 months  \
# participant
# pfizer01                                       NaN
# pfizer02                                       NaN
# pfizer04                              61062.191530
# pfizer06                              33152.879030
# pfizer07                              19171.261470
# pfizer10                              31580.977780
# pfizer13                              25181.137040
# pfizer14                              35996.525560
# pfizer24                              16667.528220
# pfizer26                                       NaN
# pfizer28                              36299.363890
# pfizer37                              31414.343850
# pfizer42                              38933.086250
# pfizer43                              16390.784870
# pfizer48                                       NaN
# pfizer52                                       NaN
# pfizer55                                       NaN
# pfizer56                              17894.138580
# pfizer57                              84022.653280
# pfizer58                              34179.831510
# pfizer59                                       NaN
# pfizer05                             121413.324600
# pfizer15                              63235.024750
# pfizer27                                       NaN
# pfizer35                                       NaN
# pfizer22                              33556.242600
# pfizer00                              70954.223750
# pfizer03                               6650.232845
# pfizer08                                       NaN
# pfizer09                              22659.494320
# pfizer11                                       NaN
# pfizer16                                       NaN
# pfizer18                              34391.781980
# pfizer19                              62665.342310
# pfizer20                              27101.330710
# pfizer21                                       NaN
# pfizer23                               9889.816129
# pfizer25                              71110.767780
# pfizer29                              45151.204420
# pfizer30                              59651.786830
# pfizer31                                       NaN
# pfizer32                              13136.215280
# pfizer33                              33841.453920
# pfizer34                              40864.574450
# pfizer36                              22599.890890
# pfizer38                              16475.251060
# pfizer39                                       NaN
# pfizer40                                       NaN
# pfizer41                                       NaN
# pfizer44                                       NaN
# pfizer45                              64267.429920
# pfizer46                              33930.915630
# pfizer47                                       NaN
# pfizer49                                       NaN
# pfizer50                                       NaN
# pfizer51                                       NaN
# pfizer53                                       NaN
# pfizer54                                       NaN
# pfizer12                                       NaN
# pfizer17                             127577.327400
#
# combined_name  h229E_S_Wuhan_IgG_day 210 / 7 months  \
# participant
# pfizer01                                        NaN
# pfizer02                                        NaN
# pfizer04                               37785.414750
# pfizer06                               23106.244750
# pfizer07                               31617.358160
# pfizer10                               40435.100120
# pfizer13                               16971.193340
# pfizer14                                5526.206530
# pfizer24                               10147.868010
# pfizer26                                        NaN
# pfizer28                               50775.293920
# pfizer37                               16741.828550
# pfizer42                               35163.200450
# pfizer43                               10323.424530
# pfizer48                                        NaN
# pfizer52                                        NaN
# pfizer55                                        NaN
# pfizer56                               15764.332170
# pfizer57                               57049.423330
# pfizer58                                8263.984555
# pfizer59                                        NaN
# pfizer05                               82933.092490
# pfizer15                               64689.590370
# pfizer27                                        NaN
# pfizer35                                        NaN
# pfizer22                               22716.668390
# pfizer00                               47761.503610
# pfizer03                               19243.152150
# pfizer08                                        NaN
# pfizer09                                4921.161237
# pfizer11                                        NaN
# pfizer16                                        NaN
# pfizer18                               11627.300170
# pfizer19                               10787.945960
# pfizer20                                7988.253817
# pfizer21                                        NaN
# pfizer23                               24066.412960
# pfizer25                               21064.661310
# pfizer29                               44148.034340
# pfizer30                               42625.402190
# pfizer31                                        NaN
# pfizer32                               11770.073950
# pfizer33                               16430.469610
# pfizer34                               15164.147490
# pfizer36                               35965.579480
# pfizer38                                8357.576808
# pfizer39                                        NaN
# pfizer40                                        NaN
# pfizer41                                        NaN
# pfizer44                                        NaN
# pfizer45                               15582.463920
# pfizer46                               28372.253220
# pfizer47                                        NaN
# pfizer49                                        NaN
# pfizer50                                        NaN
# pfizer51                                        NaN
# pfizer53                                        NaN
# pfizer54                                        NaN
# pfizer12                                        NaN
# pfizer17                               10172.192080
#
# combined_name  Wuhan_RBD_Wuhan_IgG_day 210 / 7 months
# participant
# pfizer01                                          NaN
# pfizer02                                          NaN
# pfizer04                                 17640.405140
# pfizer06                                  9763.875976
# pfizer07                                  4799.948595
# pfizer10                                 10792.525110
# pfizer13                                  7267.111653
# pfizer14                                  2117.686940
# pfizer24                                  1311.305916
# pfizer26                                          NaN
# pfizer28                                 11010.582520
# pfizer37                                  6888.596956
# pfizer42                                  5457.409734
# pfizer43                                  2517.016196
# pfizer48                                          NaN
# pfizer52                                          NaN
# pfizer55                                          NaN
# pfizer56                                 11157.919840
# pfizer57                                  3512.856333
# pfizer58                                 17530.705550
# pfizer59                                          NaN
# pfizer05                                  5202.518706
# pfizer15                                121429.105000
# pfizer27                                          NaN
# pfizer35                                          NaN
# pfizer22                                  5333.406927
# pfizer00                                 23741.443130
# pfizer03                                  3104.479552
# pfizer08                                          NaN
# pfizer09                                  6499.912267
# pfizer11                                          NaN
# pfizer16                                          NaN
# pfizer18                                 14297.049310
# pfizer19                                  5832.409328
# pfizer20                                  7201.283567
# pfizer21                                          NaN
# pfizer23                                  5301.402021
# pfizer25                                 35092.053670
# pfizer29                                  7907.452853
# pfizer30                                 13000.374260
# pfizer31                                          NaN
# pfizer32                                  3981.547386
# pfizer33                                  3456.634277
# pfizer34                                 13755.672360
# pfizer36                                  5514.545330
# pfizer38                                  4807.385095
# pfizer39                                          NaN
# pfizer40                                          NaN
# pfizer41                                          NaN
# pfizer44                                          NaN
# pfizer45                                  4123.343836
# pfizer46                                  3086.963182
# pfizer47                                          NaN
# pfizer49                                          NaN
# pfizer50                                          NaN
# pfizer51                                          NaN
# pfizer53                                          NaN
# pfizer54                                          NaN
# pfizer12                                          NaN
# pfizer17                                 20947.117880
#
# [60 rows x 90 columns]

# %%
variable_info
# Out:
#                                         virus target variant_plate_type  \
# combined_name
# Wuhan_S_Wuhan_IgG_boostD1/2             Wuhan      S              Wuhan
# NL63_S_Wuhan_IgG_boostD1/2               NL63      S              Wuhan
# Wuhan_N_Wuhan_IgG_boostD1/2             Wuhan      N              Wuhan
# CoV_S_Wuhan_IgG_boostD1/2                 CoV      S              Wuhan
# Wuhan_NTD_Wuhan_IgG_boostD1/2           Wuhan    NTD              Wuhan
# ...                                       ...    ...                ...
# Wuhan_NTD_Wuhan_IgG_day 210 / 7 months  Wuhan    NTD              Wuhan
# HKU1_S_Wuhan_IgG_day 210 / 7 months      HKU1      S              Wuhan
# OC43_S_Wuhan_IgG_day 210 / 7 months      OC43      S              Wuhan
# h229E_S_Wuhan_IgG_day 210 / 7 months    h229E      S              Wuhan
# Wuhan_RBD_Wuhan_IgG_day 210 / 7 months  Wuhan    RBD              Wuhan
#
#                                        antibody           timepoint
# combined_name
# Wuhan_S_Wuhan_IgG_boostD1/2                 IgG           boostD1/2
# NL63_S_Wuhan_IgG_boostD1/2                  IgG           boostD1/2
# Wuhan_N_Wuhan_IgG_boostD1/2                 IgG           boostD1/2
# CoV_S_Wuhan_IgG_boostD1/2                   IgG           boostD1/2
# Wuhan_NTD_Wuhan_IgG_boostD1/2               IgG           boostD1/2
# ...                                         ...                 ...
# Wuhan_NTD_Wuhan_IgG_day 210 / 7 months      IgG  day 210 / 7 months
# HKU1_S_Wuhan_IgG_day 210 / 7 months         IgG  day 210 / 7 months
# OC43_S_Wuhan_IgG_day 210 / 7 months         IgG  day 210 / 7 months
# h229E_S_Wuhan_IgG_day 210 / 7 months        IgG  day 210 / 7 months
# Wuhan_RBD_Wuhan_IgG_day 210 / 7 months      IgG  day 210 / 7 months
#
# [90 rows x 5 columns]

# %%
# attach status

vaccine_participants = vaccine_participants.set_index("PID")
vaccine_participants["Status"] = "Vaccinee"
# reorder
vaccine_participants = vaccine_participants.loc[vaccine_df_pivot.index]

# confirm same order
assert_array_equal(vaccine_participants.index, vaccine_df_pivot.index)

vaccine_participants
# Out:
#             COVID Positive Ever?    Status
# participant
# pfizer01                      No  Vaccinee
# pfizer02                      No  Vaccinee
# pfizer04                      No  Vaccinee
# pfizer06                      No  Vaccinee
# pfizer07                      No  Vaccinee
# pfizer10                      No  Vaccinee
# pfizer13                      No  Vaccinee
# pfizer14                      No  Vaccinee
# pfizer24                      No  Vaccinee
# pfizer26                     NaN  Vaccinee
# pfizer28                      No  Vaccinee
# pfizer37                      No  Vaccinee
# pfizer42                      No  Vaccinee
# pfizer43                      No  Vaccinee
# pfizer48                      No  Vaccinee
# pfizer52                      No  Vaccinee
# pfizer55                      No  Vaccinee
# pfizer56                      No  Vaccinee
# pfizer57                      No  Vaccinee
# pfizer58                      No  Vaccinee
# pfizer59                      No  Vaccinee
# pfizer05                      No  Vaccinee
# pfizer15                     Yes  Vaccinee
# pfizer27                      No  Vaccinee
# pfizer35                      No  Vaccinee
# pfizer22                     Yes  Vaccinee
# pfizer00                      No  Vaccinee
# pfizer03                      No  Vaccinee
# pfizer08                      No  Vaccinee
# pfizer09                      No  Vaccinee
# pfizer11                      No  Vaccinee
# pfizer16                      No  Vaccinee
# pfizer18                      No  Vaccinee
# pfizer19                      No  Vaccinee
# pfizer20                      No  Vaccinee
# pfizer21                      No  Vaccinee
# pfizer23                      No  Vaccinee
# pfizer25                     Yes  Vaccinee
# pfizer29                      No  Vaccinee
# pfizer30                      No  Vaccinee
# pfizer31                      No  Vaccinee
# pfizer32                     Yes  Vaccinee
# pfizer33                      No  Vaccinee
# pfizer34                      No  Vaccinee
# pfizer36                      No  Vaccinee
# pfizer38                      No  Vaccinee
# pfizer39                     NaN  Vaccinee
# pfizer40                      No  Vaccinee
# pfizer41                     NaN  Vaccinee
# pfizer44                      No  Vaccinee
# pfizer45                      No  Vaccinee
# pfizer46                      No  Vaccinee
# pfizer47                      No  Vaccinee
# pfizer49                      No  Vaccinee
# pfizer50                      No  Vaccinee
# pfizer51                      No  Vaccinee
# pfizer53                      No  Vaccinee
# pfizer54                      No  Vaccinee
# pfizer12                      No  Vaccinee
# pfizer17                      No  Vaccinee

# %%
# anndata requires string indices
vaccine_participants.index = vaccine_participants.index.astype(str)
vaccine_df_pivot.index = vaccine_df_pivot.index.astype(str)

# %%
adata_vaccine = anndata.AnnData(
    X=vaccine_df_pivot, obs=vaccine_participants, var=variable_info
)
adata_vaccine
# Out:
# AnnData object with n_obs × n_vars = 60 × 90
#     obs: 'COVID Positive Ever?', 'Status'
#     var: 'virus', 'target', 'variant_plate_type', 'antibody', 'timepoint'

# %%
adata_vaccine.var
# Out:
#                                         virus target variant_plate_type  \
# combined_name
# Wuhan_S_Wuhan_IgG_boostD1/2             Wuhan      S              Wuhan
# NL63_S_Wuhan_IgG_boostD1/2               NL63      S              Wuhan
# Wuhan_N_Wuhan_IgG_boostD1/2             Wuhan      N              Wuhan
# CoV_S_Wuhan_IgG_boostD1/2                 CoV      S              Wuhan
# Wuhan_NTD_Wuhan_IgG_boostD1/2           Wuhan    NTD              Wuhan
# ...                                       ...    ...                ...
# Wuhan_NTD_Wuhan_IgG_day 210 / 7 months  Wuhan    NTD              Wuhan
# HKU1_S_Wuhan_IgG_day 210 / 7 months      HKU1      S              Wuhan
# OC43_S_Wuhan_IgG_day 210 / 7 months      OC43      S              Wuhan
# h229E_S_Wuhan_IgG_day 210 / 7 months    h229E      S              Wuhan
# Wuhan_RBD_Wuhan_IgG_day 210 / 7 months  Wuhan    RBD              Wuhan
#
#                                        antibody           timepoint
# combined_name
# Wuhan_S_Wuhan_IgG_boostD1/2                 IgG           boostD1/2
# NL63_S_Wuhan_IgG_boostD1/2                  IgG           boostD1/2
# Wuhan_N_Wuhan_IgG_boostD1/2                 IgG           boostD1/2
# CoV_S_Wuhan_IgG_boostD1/2                   IgG           boostD1/2
# Wuhan_NTD_Wuhan_IgG_boostD1/2               IgG           boostD1/2
# ...                                         ...                 ...
# Wuhan_NTD_Wuhan_IgG_day 210 / 7 months      IgG  day 210 / 7 months
# HKU1_S_Wuhan_IgG_day 210 / 7 months         IgG  day 210 / 7 months
# OC43_S_Wuhan_IgG_day 210 / 7 months         IgG  day 210 / 7 months
# h229E_S_Wuhan_IgG_day 210 / 7 months        IgG  day 210 / 7 months
# Wuhan_RBD_Wuhan_IgG_day 210 / 7 months      IgG  day 210 / 7 months
#
# [90 rows x 5 columns]

# %%
adata_vaccine.obs["Status"].value_counts()
# Out:
# Vaccinee    60
# Name: Status, dtype: int64

# %%
adata_vaccine.write(
    f"{config.paths.generated_data_dir}/partial.pfizer_vaccine.coronavirus_plate.h5"
)
# Out:
# ... storing 'COVID Positive Ever?' as categorical
# ... storing 'Status' as categorical
# ... storing 'virus' as categorical
# ... storing 'target' as categorical
# ... storing 'variant_plate_type' as categorical
# ... storing 'antibody' as categorical
# ... storing 'timepoint' as categorical
